# %% [markdown]
# # **Week 4: Lab Exercises for COMP499/691 Conversational AI**

# %% [markdown]
# The goal of this lab is to familiarize yourself with Transformer-based Sequence-to-Sequence learning. We will work on the same task as the previous lab, but we will ask you to implement a Transformer-based model.
#
# In the tutorial, we implemented RNN and Transformer-based systems from scratch. In this lab, we will implement the two paradigms using SpeechBrain.
#
# Let's first refresh the tasks we would like to solve:
#
#
# ## **Task Description**
#
# A lucky team of archeologists just did an amazing discovery. They found a document reporting some text in English and some text in an ancient language called Ignotush. The archeologists think that for each sentence in English, there is a corresponding translation in the unknown language (parallel corpus).
# So far, many documents written in Ignotush have been found, but this is the only document reporting on both Ignotush and English.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The team of archeologists worked very hard on this document. They hope this document can help translate all the other ones available in Ignotush.
#
# They first contacted a team of linguists, but they had a hard time learning something useful. At some point, one of the archeologists proposed exploring machine learning techniques and contacted you for help with this problem.
#
# **Run the code below** to download the data.

# %%
# !gdown 1EtiJlE_FT413nIqqh8yiURiuR6d3DSZF
# !gdown 1ScPA77G1gu9kh6WKzNyy9h_VgplWisHl
# !gdown 19QlNE8u7YPLdzvFh0UexDTLCH51LwgZz
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1EtiJlE_FT413nIqqh8yiURiuR6d3DSZF
# To: /content/train.csv
# 100% 104k/104k [00:00<00:00, 67.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ScPA77G1gu9kh6WKzNyy9h_VgplWisHl
# To: /content/valid.csv
# 100% 20.7k/20.7k [00:00<00:00, 45.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=19QlNE8u7YPLdzvFh0UexDTLCH51LwgZz
# To: /content/test.csv
# 100% 20.9k/20.9k [00:00<00:00, 28.8MB/s]

# %% [markdown]
# Use dropbox, if download from gdrive does not work:

# %%
# %%capture
# !wget -O train.csv  https://www.dropbox.com/scl/fi/tokbl3vuy20e46x3udvrm/train.csv?rlkey=6xig36d642ch0n31qk8drm3ry&dl=0
# !wget -O valid.csv  https://www.dropbox.com/scl/fi/q0zxf2digbuzy8xozqq1z/valid.csv?rlkey=57hma3bj2et87puc88k1coei1&dl=0
# !wget -O test.csv   https://www.dropbox.com/scl/fi/pq7goblr0xfkoyn7utj1g/test.csv?rlkey=8pv3c2agjml2yyy8mi39h676k&dl=0

# %% [markdown]
# The dataset is split into training, validation, and test data as you can see by opening `train.csv`, `valid.csv`, and `test.csv`.
#
# For every sentence in English, you have the corresponding sentence in Ignotush.
#
# We have 1000 sentences for training, 200 for validation, and 200 for testing.
#
# This problem is very popular in machine learning and it is called *machine translation* (the famous Google Translate uses deep learning techniques not too far away from those that we will use in this lab).

# %% [markdown]
# **Run the code below** to install speechbrain.

# %%
# %%capture
# !pip install speechbrain

# %% [markdown]
# ## **Exercise 1: Transformers**
#
# You want now to try another architecture by replacing RNNs with Transformers.
#
# **Run the code below** to store the hyperparameters for the Tranformer-based encoder-decoder model.

# %%
# %%file Transformer.yaml
# # ############################################################################
# # Model: E2E with attention-based Machine Translation
# # Encoder: Transformer
# # Decoder: Transformer
# # Tokens: Chars
# # losses: NLL
# # Training: Ignotush
# ##############################################################################
#
# # Seed needs to be set at top of yaml, before objects with parameters are instantiated
# seed: 1986
# __set_seed: !apply:torch.manual_seed [!ref <seed>]
#
# # Folder set up
# output_folder: !ref results/Transformer/<seed>
# wer_file: !ref <output_folder>/wer.txt
# save_folder: !ref <output_folder>/save
# train_log: !ref <output_folder>/train_log.txt
# cer_file: !ref <output_folder>/test_cer.txt # file were to store the final character error rate on the test set.
#
# # Path where data manifest files are stored
# train_annotation: train.csv
# valid_annotation: valid.csv
# test_annotation: test.csv
#
# # The train logger writes training statistics to a file, as well as stdout.
# train_logger: !new:speechbrain.utils.train_logger.FileTrainLogger
#     save_file: !ref <train_log>
#
# # Training parameters
# number_of_epochs: 100
# batch_size: 100
# lr: 0.01
# lr_final: 0.001
#
#
# # Dataloader options
# train_dataloader_opts:
#     batch_size: !ref <batch_size>
#
# valid_dataloader_opts:
#     batch_size: !ref <batch_size>
#
# test_dataloader_opts:
#     batch_size: !ref <batch_size>
#
#
# # Vocabulary sizes
# voc_size_english: 31
# voc_size_ignotush: 32
#
# # Indexes for begin-of-sentence (bos)
# # and end-of-sentence (eos)
# blank_index: 0 # This special tokes is for padding
# bos_index: 1
# eos_index: 2
#
# # Encoder Parameters
# d_model: 64
# nhead: 4
# num_encoder_layers: 1
# num_decoder_layers: 1
# dim_feedforward: 64
# dropout: 0.1
#
#
# # The first object passed to the Brain class is this "Epoch Counter"
# # which is saved by the Checkpointer so that training can be resumed
# # if it gets interrupted at any point.
# epoch_counter: !new:speechbrain.utils.epoch_loop.EpochCounter
#     limit: !ref <number_of_epochs>
#
#
# Seq2SeqTransformer: !new:torch.nn.Transformer
#     d_model: !ref <d_model>
#     nhead: !ref <nhead>
#     num_encoder_layers: !ref <num_encoder_layers>
#     num_decoder_layers: !ref <num_decoder_layers>
#     dim_feedforward: !ref <dim_feedforward>
#     dropout: !ref <dropout>
#     batch_first: True
#
#
# encoder_emb: !new:torch.nn.Embedding
#     num_embeddings: !ref <voc_size_ignotush>
#     embedding_dim: !ref <d_model>
#     padding_idx: !ref <blank_index>
#
#
# pos_emb_enc: !new:speechbrain.lobes.models.transformer.Transformer.PositionalEncoding
#     input_size: !ref <d_model>
#     max_len: 200
#
# pos_emb_dec: !new:speechbrain.lobes.models.transformer.Transformer.PositionalEncoding
#     input_size: !ref <d_model>
#     max_len: 200
#
# decoder_emb: !new:torch.nn.Embedding
#     num_embeddings: !ref <voc_size_english>
#     embedding_dim: !ref <d_model>
#     padding_idx: !ref <blank_index>
#
# # Linear transformation on the top of the decoder.
# seq_lin: !new:speechbrain.nnet.linear.Linear
#     input_size: !ref <d_model>
#     n_neurons: !ref <voc_size_english>
#
#
# # Masks
# lookahead_mask: !name:speechbrain.lobes.models.transformer.Transformer.get_lookahead_mask
# padding_mask: !name:speechbrain.lobes.models.transformer.Transformer.get_key_padding_mask
#
#
# # Final softmax (for log posteriors computation).
# log_softmax: !new:speechbrain.nnet.activations.Softmax
#     apply_log: True
#
#
#
# # Objects in "modules" dict will have their parameters moved to the correct
# # device, as well as having train()/eval() called on them by the Brain class
# modules:
#     Seq2SeqTransformer: !ref <Seq2SeqTransformer>
#     encoder_emb: !ref <encoder_emb>
#     pos_emb_enc: !ref <pos_emb_enc>
#     decoder_emb: !ref <decoder_emb>
#     pos_emb_dec: !ref <pos_emb_dec>
#     seq_lin: !ref <seq_lin>
#
#
# # Gathering all the submodels in a single model object.
# model: !new:torch.nn.ModuleList
#     - - !ref <Seq2SeqTransformer>
#       - !ref <encoder_emb>
#       - !ref <seq_lin>
#       - !ref <decoder_emb>
#
#
# # This function manages learning rate annealing over the epochs.
# lr_annealing: !new:speechbrain.nnet.schedulers.LinearScheduler
#     initial_value: !ref <lr>
#     final_value: !ref <lr_final>
#     epoch_count: !ref <number_of_epochs>
#
# # This optimizer will be constructed by the Brain class after all parameters
# # are moved to the correct device. Then it will be added to the checkpointer.
# opt_class: !name:torch.optim.Adam
#     lr: !ref <lr>
#
# # This object is used for saving the state of training both so that it
# # can be resumed if it gets interrupted, and also so that the best checkpoint
# # can be later loaded for evaluation or inference.
# checkpointer: !new:speechbrain.utils.checkpoints.Checkpointer
#     checkpoints_dir: !ref <save_folder>
#     recoverables:
#         model: !ref <model>
#         counter: !ref <epoch_counter>
# Out:
# Writing Transformer.yaml

# %% [markdown]
# **Complete the code below** to implement the Transformer system. The code must be consistent with what is declared in the YAML file. You need to apply proper masking to the input and output elements.

# %%
# %%file train_transformer.py
#!/usr/bin/env/python3
"""Recipe for training a sequence-to-sequence machine translation system
on "ignotush".
The system employs a Transformer encoder, a decoder, and an attention mechanism
between them.

To run this recipe, do the following:
> python train.py hparams/Transformers.yaml

With the default hyperparameters, the system employs a Transformer encoder and decoder.

The neural network is trained with the negative-log likelihood objective and
characters are used as basic tokens for both english and ignotush.
"""

import os
import sys
import torch
import logging
import speechbrain as sb
from hyperpyyaml import load_hyperpyyaml

logger = logging.getLogger(__name__)


# Brain class for speech recognition training
class Translate(sb.Brain):
    """Class that manages the training loop. See speechbrain.core.Brain."""

    def compute_forward(self, batch, stage):
        """Runs all the computation of the CTC + seq2seq ASR. It returns the
        posterior probabilities of the CTC and seq2seq networks.

        Arguments
        ---------
        batch : PaddedBatch
            This batch object contains all the relevant tensors for computation.
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, or sb.Stage.TEST.

        Returns
        -------
        predictions : torch.tensor
            Log-probabilities predicted by the decoder.

        At validation/test time, it returns the predicted tokens as well.
        """
        # We first move the batch to the appropriate device.
        # Your code here. Aim for 1 line.
        batch = batch.to(self.device)

        # Unpacking ignotush_encoded_chars and english_encoded_chars_bos
        # Your code here. Aim for 1 line.
        enc_ignotush, inp_lens = batch.ignotush_encoded_chars
        enc_english_bos,  out_lens = batch.english_encoded_chars_bos

        # Input embeddings
        # Your code here. Aim for 1 line.
        enc_emb = self.modules.encoder_emb(enc_ignotush)

        # Positional Embeddings
        # Your code here. Aim for 1 line.
        pos_emb_enc = self.modules.pos_emb_enc(enc_emb)

        # Summing up embeddings
        # Your code here. Aim for 1 line.
        enc_emb = enc_emb + pos_emb_enc

        # Decoding embeddings
        # Your code here. Aim for 3 lines.
        dec_emb = self.modules.decoder_emb(enc_english_bos)
        pos_emb_dec = self.modules.pos_emb_dec(dec_emb) # Positional Embeddings
        dec_emb = dec_emb + pos_emb_dec # Sum


        # Getting target mask (to avoid looking ahead)
        # Your code here. Aim for 1 line.
        tgt_mask = self.hparams.lookahead_mask(dec_emb)

        # Getting the source mask (all zeros is fine in this case to allow the
        # network to embed both past and future contect)
        # Your code here. Aim for 1 line.

        # src_mask = torch.zeros_like(enc_emb).to(self.device)
        src_mask = torch.zeros(enc_emb.shape[1],enc_emb.shape[1]).to(self.device)

        # Padding masks for source and targets (use padding_mas)
        # Your code here. Aim for 2 lines.
        src_key_padding_mask = self.hparams.padding_mask(enc_emb, 0)
        tgt_key_padding_mask = self.hparams.padding_mask(dec_emb, 0)


        # Running the Seq2Seq Transformer
        # Your code here. Aim for 1 line.
        decoder_outputs = self.modules.Seq2SeqTransformer(enc_emb, dec_emb, src_mask = src_mask, tgt_mask = tgt_mask, src_key_padding_mask = src_key_padding_mask, tgt_key_padding_mask = tgt_key_padding_mask)

        # Compute logits
        # Your code here. Aim for 1 line.
        logits = self.modules.seq_lin(decoder_outputs)

        # Apply log softmax
        # Your code here. Aim for 1 line.
        predictions = self.hparams.log_softmax(logits)


        if stage == sb.Stage.TEST:

            # Greedy Decoding
            hyps = predictions.argmax(-1)

            # getting the first index where the prediciton is eos_index
            stop_indexes = (hyps==self.hparams.eos_index).int()
            stop_indexes = stop_indexes.argmax(dim=1)

            # Converting hyps from indexes to chars
            hyp_lst = []
            for hyp, stop_ind in zip(hyps, stop_indexes):
                # in some cases the eos in not observed (e.g, for the last sentence
                # in the batch)
                if stop_ind == 0:
                    stop_ind = -1
                # Stopping when eos is observed
                hyp = hyp[0:stop_ind]
                # From index to character
                hyp_lst.append(self.label_encoder.decode_ndim(hyp))
            return predictions, hyp_lst

        return predictions


    def compute_objectives(self, predictions, batch, stage):
        """Computes the loss given the predicted and targeted outputs.

        Arguments
        ---------
        predictions : torch.tTensor
            The output tensor from `compute_forward`.
        batch : PaddedBatch
            This batch object contains all the relevant tensors for computation.
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, or sb.Stage.TEST.

        Returns
        -------
        loss : torch.Tensor
            A one-element tensor used for backpropagating the gradient.
        """
        # Reading english_encoded_chars_eos
        # Your code here. Aim for 1 line.
        enc_english_eos, english_lens = batch.english_encoded_chars_eos


        # Reading the predictions
        if stage == sb.Stage.TEST:
          predictions, hyp_lst = predictions

          for id, label, hyp in zip(batch.id, batch.english_chars, hyp_lst):
              print(id)
              print("REF: " + ''.join(label))
              print("HYP: " + ''.join(hyp))
              print('--------')

        # Compute the nnl_loss
        # Your code here. Aim for 1 line.
        loss = sb.nnet.losses.nll_loss(predictions, enc_english_eos, english_lens)

        return loss


    def on_stage_end(self, stage, stage_loss, epoch):
        """Gets called at the end of an epoch.

        Arguments
        ---------
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, sb.Stage.TEST
        stage_loss : float
            The average loss for all of the data processed in this stage.
        epoch : int
            The currently-starting epoch. This is passed
            `None` during the test stage.
        """

        # Store the train loss until the validation stage.
        stage_stats = {"loss": stage_loss}
        if stage == sb.Stage.TRAIN:
            self.train_stats = stage_stats


        # Perform end-of-iteration things, like annealing, logging, etc.
        elif stage == sb.Stage.VALID:


            # Update learning rate
            old_lr, new_lr = self.hparams.lr_annealing(epoch)
            sb.nnet.schedulers.update_learning_rate(self.optimizer, new_lr)

            # The train_logger writes a summary to stdout and to the logfile.
            self.hparams.train_logger.log_stats(
                stats_meta={"epoch": epoch, "lr": old_lr},
                train_stats=self.train_stats,
                valid_stats={
                    "loss": stage_loss,
                },
            )
            # Save the current checkpoint and delete previous checkpoints.
            self.checkpointer.save_and_keep_only(
                meta={"loss": stage_stats["loss"]}, min_keys=["loss"],
            )

        # We also write statistics about test data to stdout and to the logfile.
        elif stage == sb.Stage.TEST:

            self.hparams.train_logger.log_stats(
                stats_meta={"Epoch loaded": self.hparams.epoch_counter.current},
                test_stats={
                    "loss": stage_loss,
                },
            )


def dataio_prepare(hparams):
    """This function prepares the datasets to be used in the brain class.
    It also defines the data processing pipeline through user-defined functions.


    Arguments
    ---------
    hparams : dict
        This dictionary is loaded from the `train.yaml` file, and it includes
        all the hyperparameters needed for dataset construction and loading.

    Returns
    -------
    datasets : dict
        Dictionary containing "train", "valid", and "test" keys that correspond
        to the DynamicItemDataset objects.
    """
    # Define text processing pipeline. We start from the raw text and then
    # split it into characters. The tokens with BOS are used for feeding
    # the decoder during training (right shifr), the tokens with EOS
    # are used for computing the cost function.
    @sb.utils.data_pipeline.takes("english")
    @sb.utils.data_pipeline.provides(
        "english_words",
        "english_chars",
        "english_encoded_chars_lst",
        "english_encoded_chars",
        "english_encoded_chars_eos",
        "english_encoded_chars_bos",
        )
    def ignotush_text_pipeline(english):
        """Processes the transcriptions to generate proper labels"""
        yield english
        english_chars = list(english)
        yield english_chars
        english_encoded_chars_lst = label_encoder.encode_sequence(english_chars)
        yield english_encoded_chars_lst
        english_encoded_chars = torch.LongTensor(english_encoded_chars_lst)
        yield english_encoded_chars
        english_encoded_chars_eos = torch.LongTensor(label_encoder.append_eos_index(english_encoded_chars_lst))
        yield english_encoded_chars_eos
        english_encoded_chars_bos = torch.LongTensor(label_encoder.prepend_bos_index(english_encoded_chars_lst))
        yield english_encoded_chars_bos

    @sb.utils.data_pipeline.takes("ignotush")
    @sb.utils.data_pipeline.provides("ignotush_words", "ignotush_chars", "ignotush_encoded_chars")
    def english_text_pipeline(ignotush):
        """Processes the transcriptions to generate proper labels"""
        yield ignotush
        ignotush_chars = list(ignotush)
        yield ignotush_chars
        ignotush_encoded_chars = torch.LongTensor(input_encoder.encode_sequence(ignotush_chars))
        yield ignotush_encoded_chars

    # Define datasets from json data manifest file
    # Define datasets sorted by ascending lengths for efficiency
    datasets = {}
    data_info = {
        "train": hparams["train_annotation"],
        "valid": hparams["valid_annotation"],
        "test": hparams["test_annotation"],
    }

    # The label encoder will assign a different integer to each element
    # in the output vocabulary
    input_encoder = sb.dataio.encoder.CTCTextEncoder()
    label_encoder = sb.dataio.encoder.CTCTextEncoder()

    for dataset in data_info:
        datasets[dataset] = sb.dataio.dataset.DynamicItemDataset.from_csv(
            csv_path=data_info[dataset],
            dynamic_items=[ignotush_text_pipeline, english_text_pipeline],
            output_keys=[
                "id",
                "english_words",
                "english_chars",
                "english_encoded_chars",
                "english_encoded_chars_eos",
                "english_encoded_chars_bos",
                "ignotush_words",
                "ignotush_chars",
                "ignotush_encoded_chars",
            ],
        )
        hparams[f"{dataset}_dataloader_opts"]["shuffle"] = True


    # Load or compute the label encoder
    inp_enc_file = os.path.join(hparams["save_folder"], "input_encoder.txt")

    # The blank symbol is used to indicate padding
    special_labels = {"blank_label": hparams["blank_index"]}

    input_encoder.load_or_create(
        path=inp_enc_file,
        from_didatasets=[datasets["train"]],
        output_key="ignotush_chars",
        special_labels=special_labels,
        sequence_input=True,
    )

    # Load or compute the label encoder
    lab_enc_file = os.path.join(hparams["save_folder"], "label_encoder.txt")
    special_labels = {
        "blank_label": hparams["blank_index"],
        "bos_label": hparams["bos_index"],
        "eos_label": hparams["eos_index"],
    }
    label_encoder.load_or_create(
        path=lab_enc_file,
        from_didatasets=[datasets["train"]],
        output_key="english_chars",
        special_labels=special_labels,
        sequence_input=True,
    )

    return datasets, label_encoder


if __name__ == "__main__":

    # Reading command line arguments
    hparams_file, run_opts, overrides = sb.parse_arguments(sys.argv[1:])

    # Load hyperparameters file with command-line overrides
    with open(hparams_file) as fin:
        hparams = load_hyperpyyaml(fin, overrides)

    # Create experiment directory
    sb.create_experiment_directory(
        experiment_directory=hparams["output_folder"],
        hyperparams_to_save=hparams_file,
        overrides=overrides,
    )


    # We can now directly create the datasets for training, valid, and test
    datasets, label_encoder = dataio_prepare(hparams)

    # Trainer initialization
    translate_brain = Translate(
        modules=hparams["modules"],
        opt_class=hparams["opt_class"],
        hparams=hparams,
        run_opts=run_opts,
        checkpointer=hparams["checkpointer"],
    )

    # Making label encoder accessible (needed for computer the character error rate)
    translate_brain.label_encoder = label_encoder

    # The `fit()` method iterates the training loop, calling the methods
    # necessary to update the parameters of the model. Since all objects
    # with changing state are managed by the Checkpointer, training can be
    # stopped at any point, and will be resumed on next call.
    translate_brain.fit(
        translate_brain.hparams.epoch_counter,
        datasets["train"],
        datasets["valid"],
        train_loader_kwargs=hparams["train_dataloader_opts"],
        valid_loader_kwargs=hparams["valid_dataloader_opts"],
    )

    # Load best checkpoint for evaluation
    test_stats = translate_brain.evaluate(
        test_set=datasets["test"],
        min_key="WER",
        test_loader_kwargs=hparams["test_dataloader_opts"],
    )
# Out:
# Writing train_transformer.py

# %% [markdown]
# **Run the code below** to train the model

# %%
# !python train_transformer.py Transformer.yaml --device='cpu'
# Out:
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: results/Transformer/1986
# speechbrain.dataio.encoder - Moving label 'p' from index 0, because '<blank>' was put at its place.
# speechbrain.dataio.encoder - Load called, but CTCTextEncoder is not empty. Loaded data will overwrite everything. This is normal if there is e.g. an unk label defined at init.
# speechbrain.dataio.encoder - Moving label 'T' from index 0, because '<blank>' was put at its place.
# speechbrain.dataio.encoder - Moving label 'H' from index 1, because '<bos>' was put at its place.
# speechbrain.dataio.encoder - Moving label 'E' from index 2, because '<eos>' was put at its place.
# speechbrain.dataio.encoder - Load called, but CTCTextEncoder is not empty. Loaded data will overwrite everything. This is normal if there is e.g. an unk label defined at init.
# speechbrain.core - 73.5k trainable parameters in Translate
# speechbrain.utils.checkpoints - Would load a checkpoint here, but none found yet.
# speechbrain.utils.epoch_loop - Going into epoch 1
#   0% 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/speechbrain/dataio/encoder.py:722: UserWarning: CTCTextEncoder.expect_len was never called: assuming category count of 31 to be correct! Sanity check your encoder using `.expect_len`. Ensure that downstream code also uses the correct size. If you are sure this does not apply to you, use `.ignore_len`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/speechbrain/dataio/encoder.py:722: UserWarning: CTCTextEncoder.expect_len was never called: assuming category count of 32 to be correct! Sanity check your encoder using `.expect_len`. Ensure that downstream code also uses the correct size. If you are sure this does not apply to you, use `.ignore_len`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:5076: UserWarning: Support for mismatched src_key_padding_mask and mask is deprecated. Use same type for both instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:5076: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# 100% 10/10 [00:06<00:00,  1.58it/s, train_loss=2.95]
# 100% 2/2 [00:00<00:00,  6.81it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.01 to 0.0099
# speechbrain.utils.train_logger - epoch: 1, lr: 1.00e-02 - train loss: 2.95 - valid loss: 2.68
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-17+00
# speechbrain.utils.epoch_loop - Going into epoch 2
# 100% 10/10 [00:03<00:00,  3.28it/s, train_loss=2.58]
# 100% 2/2 [00:00<00:00,  5.31it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0099 to 0.0098
# speechbrain.utils.train_logger - epoch: 2, lr: 9.91e-03 - train loss: 2.58 - valid loss: 2.49
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-20+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-17+00
# speechbrain.utils.epoch_loop - Going into epoch 3
# 100% 10/10 [00:03<00:00,  3.09it/s, train_loss=2.47]
# 100% 2/2 [00:00<00:00,  6.80it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0098 to 0.0097
# speechbrain.utils.train_logger - epoch: 3, lr: 9.82e-03 - train loss: 2.47 - valid loss: 2.44
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-24+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-20+00
# speechbrain.utils.epoch_loop - Going into epoch 4
# 100% 10/10 [00:02<00:00,  3.34it/s, train_loss=2.42]
# 100% 2/2 [00:00<00:00,  4.35it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0097 to 0.0096
# speechbrain.utils.train_logger - epoch: 4, lr: 9.73e-03 - train loss: 2.42 - valid loss: 2.40
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-27+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-24+00
# speechbrain.utils.epoch_loop - Going into epoch 5
# 100% 10/10 [00:03<00:00,  2.89it/s, train_loss=2.38]
# 100% 2/2 [00:00<00:00,  6.35it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0096 to 0.0095
# speechbrain.utils.train_logger - epoch: 5, lr: 9.64e-03 - train loss: 2.38 - valid loss: 2.36
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-31+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-27+00
# speechbrain.utils.epoch_loop - Going into epoch 6
# 100% 10/10 [00:02<00:00,  3.51it/s, train_loss=2.34]
# 100% 2/2 [00:00<00:00,  7.00it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0095 to 0.0095
# speechbrain.utils.train_logger - epoch: 6, lr: 9.55e-03 - train loss: 2.34 - valid loss: 2.32
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-34+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-31+00
# speechbrain.utils.epoch_loop - Going into epoch 7
# 100% 10/10 [00:02<00:00,  3.80it/s, train_loss=2.28]
# 100% 2/2 [00:00<00:00,  7.17it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0095 to 0.0094
# speechbrain.utils.train_logger - epoch: 7, lr: 9.45e-03 - train loss: 2.28 - valid loss: 2.26
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-37+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-34+00
# speechbrain.utils.epoch_loop - Going into epoch 8
# 100% 10/10 [00:03<00:00,  2.66it/s, train_loss=2.23]
# 100% 2/2 [00:00<00:00,  5.38it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0094 to 0.0093
# speechbrain.utils.train_logger - epoch: 8, lr: 9.36e-03 - train loss: 2.23 - valid loss: 2.21
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-41+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-37+00
# speechbrain.utils.epoch_loop - Going into epoch 9
# 100% 10/10 [00:03<00:00,  2.98it/s, train_loss=2.17]
# 100% 2/2 [00:00<00:00,  6.76it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0093 to 0.0092
# speechbrain.utils.train_logger - epoch: 9, lr: 9.27e-03 - train loss: 2.17 - valid loss: 2.14
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-45+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-41+00
# speechbrain.utils.epoch_loop - Going into epoch 10
# 100% 10/10 [00:03<00:00,  3.11it/s, train_loss=2.09]
# 100% 2/2 [00:00<00:00,  6.61it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0092 to 0.0091
# speechbrain.utils.train_logger - epoch: 10, lr: 9.18e-03 - train loss: 2.09 - valid loss: 2.05
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-48+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-45+00
# speechbrain.utils.epoch_loop - Going into epoch 11
# 100% 10/10 [00:03<00:00,  3.20it/s, train_loss=1.99]
# 100% 2/2 [00:00<00:00,  4.49it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0091 to 0.009
# speechbrain.utils.train_logger - epoch: 11, lr: 9.09e-03 - train loss: 1.99 - valid loss: 1.94
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-52+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-48+00
# speechbrain.utils.epoch_loop - Going into epoch 12
# 100% 10/10 [00:03<00:00,  2.91it/s, train_loss=1.88]
# 100% 2/2 [00:00<00:00,  6.99it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.009 to 0.0089
# speechbrain.utils.train_logger - epoch: 12, lr: 9.00e-03 - train loss: 1.88 - valid loss: 1.72
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-56+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-52+00
# speechbrain.utils.epoch_loop - Going into epoch 13
# 100% 10/10 [00:03<00:00,  3.22it/s, train_loss=1.7]
# 100% 2/2 [00:00<00:00,  6.98it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0089 to 0.0088
# speechbrain.utils.train_logger - epoch: 13, lr: 8.91e-03 - train loss: 1.70 - valid loss: 1.51
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-59+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-56+00
# speechbrain.utils.epoch_loop - Going into epoch 14
# 100% 10/10 [00:03<00:00,  3.31it/s, train_loss=1.52]
# 100% 2/2 [00:00<00:00,  6.59it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0088 to 0.0087
# speechbrain.utils.train_logger - epoch: 14, lr: 8.82e-03 - train loss: 1.52 - valid loss: 1.28
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-03+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-54-59+00
# speechbrain.utils.epoch_loop - Going into epoch 15
# 100% 10/10 [00:03<00:00,  2.55it/s, train_loss=1.35]
# 100% 2/2 [00:00<00:00,  7.23it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0087 to 0.0086
# speechbrain.utils.train_logger - epoch: 15, lr: 8.73e-03 - train loss: 1.35 - valid loss: 1.10
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-07+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-03+00
# speechbrain.utils.epoch_loop - Going into epoch 16
# 100% 10/10 [00:02<00:00,  3.34it/s, train_loss=1.19]
# 100% 2/2 [00:00<00:00,  7.50it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0086 to 0.0085
# speechbrain.utils.train_logger - epoch: 16, lr: 8.64e-03 - train loss: 1.19 - valid loss: 9.50e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-10+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-07+00
# speechbrain.utils.epoch_loop - Going into epoch 17
# 100% 10/10 [00:02<00:00,  3.36it/s, train_loss=1.07]
# 100% 2/2 [00:00<00:00,  6.72it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0085 to 0.0085
# speechbrain.utils.train_logger - epoch: 17, lr: 8.55e-03 - train loss: 1.07 - valid loss: 8.29e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-14+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-10+00
# speechbrain.utils.epoch_loop - Going into epoch 18
# 100% 10/10 [00:02<00:00,  3.39it/s, train_loss=0.964]
# 100% 2/2 [00:00<00:00,  4.63it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0085 to 0.0084
# speechbrain.utils.train_logger - epoch: 18, lr: 8.45e-03 - train loss: 9.64e-01 - valid loss: 7.48e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-17+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-14+00
# speechbrain.utils.epoch_loop - Going into epoch 19
# 100% 10/10 [00:03<00:00,  2.76it/s, train_loss=0.891]
# 100% 2/2 [00:00<00:00,  7.10it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0084 to 0.0083
# speechbrain.utils.train_logger - epoch: 19, lr: 8.36e-03 - train loss: 8.91e-01 - valid loss: 7.07e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-21+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-17+00
# speechbrain.utils.epoch_loop - Going into epoch 20
# 100% 10/10 [00:03<00:00,  3.31it/s, train_loss=0.812]
# 100% 2/2 [00:00<00:00,  7.22it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0083 to 0.0082
# speechbrain.utils.train_logger - epoch: 20, lr: 8.27e-03 - train loss: 8.12e-01 - valid loss: 6.47e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-24+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-21+00
# speechbrain.utils.epoch_loop - Going into epoch 21
# 100% 10/10 [00:03<00:00,  3.11it/s, train_loss=0.763]
# 100% 2/2 [00:00<00:00,  6.53it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0082 to 0.0081
# speechbrain.utils.train_logger - epoch: 21, lr: 8.18e-03 - train loss: 7.63e-01 - valid loss: 5.72e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-28+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-24+00
# speechbrain.utils.epoch_loop - Going into epoch 22
# 100% 10/10 [00:03<00:00,  2.54it/s, train_loss=0.716]
# 100% 2/2 [00:00<00:00,  6.75it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0081 to 0.008
# speechbrain.utils.train_logger - epoch: 22, lr: 8.09e-03 - train loss: 7.16e-01 - valid loss: 5.23e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-32+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-28+00
# speechbrain.utils.epoch_loop - Going into epoch 23
# 100% 10/10 [00:03<00:00,  3.08it/s, train_loss=0.669]
# 100% 2/2 [00:00<00:00,  7.22it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.008 to 0.0079
# speechbrain.utils.train_logger - epoch: 23, lr: 8.00e-03 - train loss: 6.69e-01 - valid loss: 5.29e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-36+00
# speechbrain.utils.epoch_loop - Going into epoch 24
# 100% 10/10 [00:03<00:00,  3.21it/s, train_loss=0.654]
# 100% 2/2 [00:00<00:00,  6.75it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0079 to 0.0078
# speechbrain.utils.train_logger - epoch: 24, lr: 7.91e-03 - train loss: 6.54e-01 - valid loss: 4.99e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-39+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-36+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-32+00
# speechbrain.utils.epoch_loop - Going into epoch 25
# 100% 10/10 [00:03<00:00,  2.85it/s, train_loss=0.619]
# 100% 2/2 [00:00<00:00,  4.37it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0078 to 0.0077
# speechbrain.utils.train_logger - epoch: 25, lr: 7.82e-03 - train loss: 6.19e-01 - valid loss: 4.72e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-43+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-39+00
# speechbrain.utils.epoch_loop - Going into epoch 26
# 100% 10/10 [00:04<00:00,  2.10it/s, train_loss=0.588]
# 100% 2/2 [00:00<00:00,  6.46it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0077 to 0.0076
# speechbrain.utils.train_logger - epoch: 26, lr: 7.73e-03 - train loss: 5.88e-01 - valid loss: 4.40e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-49+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-43+00
# speechbrain.utils.epoch_loop - Going into epoch 27
# 100% 10/10 [00:03<00:00,  3.07it/s, train_loss=0.562]
# 100% 2/2 [00:00<00:00,  6.75it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0076 to 0.0075
# speechbrain.utils.train_logger - epoch: 27, lr: 7.64e-03 - train loss: 5.62e-01 - valid loss: 4.36e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-52+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-49+00
# speechbrain.utils.epoch_loop - Going into epoch 28
# 100% 10/10 [00:03<00:00,  2.68it/s, train_loss=0.551]
# 100% 2/2 [00:00<00:00,  4.80it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0075 to 0.0075
# speechbrain.utils.train_logger - epoch: 28, lr: 7.55e-03 - train loss: 5.51e-01 - valid loss: 4.21e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-57+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-52+00
# speechbrain.utils.epoch_loop - Going into epoch 29
# 100% 10/10 [00:02<00:00,  3.49it/s, train_loss=0.521]
# 100% 2/2 [00:00<00:00,  7.03it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0075 to 0.0074
# speechbrain.utils.train_logger - epoch: 29, lr: 7.45e-03 - train loss: 5.21e-01 - valid loss: 3.94e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-00+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-55-57+00
# speechbrain.utils.epoch_loop - Going into epoch 30
# 100% 10/10 [00:03<00:00,  3.29it/s, train_loss=0.484]
# 100% 2/2 [00:00<00:00,  6.11it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0074 to 0.0073
# speechbrain.utils.train_logger - epoch: 30, lr: 7.36e-03 - train loss: 4.84e-01 - valid loss: 3.61e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-03+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-00+00
# speechbrain.utils.epoch_loop - Going into epoch 31
# 100% 10/10 [00:03<00:00,  3.23it/s, train_loss=0.445]
# 100% 2/2 [00:00<00:00,  4.78it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0073 to 0.0072
# speechbrain.utils.train_logger - epoch: 31, lr: 7.27e-03 - train loss: 4.45e-01 - valid loss: 3.42e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-07+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-03+00
# speechbrain.utils.epoch_loop - Going into epoch 32
# 100% 10/10 [00:03<00:00,  2.66it/s, train_loss=0.426]
# 100% 2/2 [00:00<00:00,  7.20it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0072 to 0.0071
# speechbrain.utils.train_logger - epoch: 32, lr: 7.18e-03 - train loss: 4.26e-01 - valid loss: 3.16e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-11+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-07+00
# speechbrain.utils.epoch_loop - Going into epoch 33
# 100% 10/10 [00:02<00:00,  3.42it/s, train_loss=0.417]
# 100% 2/2 [00:00<00:00,  7.03it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0071 to 0.007
# speechbrain.utils.train_logger - epoch: 33, lr: 7.09e-03 - train loss: 4.17e-01 - valid loss: 2.88e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-15+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-11+00
# speechbrain.utils.epoch_loop - Going into epoch 34
# 100% 10/10 [00:03<00:00,  3.27it/s, train_loss=0.405]
# 100% 2/2 [00:00<00:00,  6.52it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.007 to 0.0069
# speechbrain.utils.train_logger - epoch: 34, lr: 7.00e-03 - train loss: 4.05e-01 - valid loss: 2.95e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-18+00
# speechbrain.utils.epoch_loop - Going into epoch 35
# 100% 10/10 [00:04<00:00,  2.35it/s, train_loss=0.371]
# 100% 2/2 [00:00<00:00,  6.87it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0069 to 0.0068
# speechbrain.utils.train_logger - epoch: 35, lr: 6.91e-03 - train loss: 3.71e-01 - valid loss: 2.63e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-23+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-15+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-18+00
# speechbrain.utils.epoch_loop - Going into epoch 36
# 100% 10/10 [00:03<00:00,  3.25it/s, train_loss=0.35]
# 100% 2/2 [00:00<00:00,  6.94it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0068 to 0.0067
# speechbrain.utils.train_logger - epoch: 36, lr: 6.82e-03 - train loss: 3.50e-01 - valid loss: 2.51e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-26+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-23+00
# speechbrain.utils.epoch_loop - Going into epoch 37
# 100% 10/10 [00:03<00:00,  3.12it/s, train_loss=0.357]
# 100% 2/2 [00:00<00:00,  6.78it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0067 to 0.0066
# speechbrain.utils.train_logger - epoch: 37, lr: 6.73e-03 - train loss: 3.57e-01 - valid loss: 2.49e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-30+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-26+00
# speechbrain.utils.epoch_loop - Going into epoch 38
# 100% 10/10 [00:03<00:00,  2.68it/s, train_loss=0.337]
# 100% 2/2 [00:00<00:00,  4.33it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0066 to 0.0065
# speechbrain.utils.train_logger - epoch: 38, lr: 6.64e-03 - train loss: 3.37e-01 - valid loss: 2.49e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-34+00
# speechbrain.utils.epoch_loop - Going into epoch 39
# 100% 10/10 [00:03<00:00,  3.17it/s, train_loss=0.326]
# 100% 2/2 [00:00<00:00,  6.71it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0065 to 0.0065
# speechbrain.utils.train_logger - epoch: 39, lr: 6.55e-03 - train loss: 3.26e-01 - valid loss: 2.53e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-38+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-34+00
# speechbrain.utils.epoch_loop - Going into epoch 40
# 100% 10/10 [00:03<00:00,  3.17it/s, train_loss=0.3]
# 100% 2/2 [00:00<00:00,  6.25it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0065 to 0.0064
# speechbrain.utils.train_logger - epoch: 40, lr: 6.45e-03 - train loss: 3.00e-01 - valid loss: 2.11e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-41+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-30+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-38+00
# speechbrain.utils.epoch_loop - Going into epoch 41
# 100% 10/10 [00:03<00:00,  2.86it/s, train_loss=0.28]
# 100% 2/2 [00:00<00:00,  4.10it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0064 to 0.0063
# speechbrain.utils.train_logger - epoch: 41, lr: 6.36e-03 - train loss: 2.80e-01 - valid loss: 1.88e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-46+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-41+00
# speechbrain.utils.epoch_loop - Going into epoch 42
# 100% 10/10 [00:03<00:00,  2.88it/s, train_loss=0.264]
# 100% 2/2 [00:00<00:00,  6.98it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0063 to 0.0062
# speechbrain.utils.train_logger - epoch: 42, lr: 6.27e-03 - train loss: 2.64e-01 - valid loss: 1.84e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-50+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-46+00
# speechbrain.utils.epoch_loop - Going into epoch 43
# 100% 10/10 [00:03<00:00,  3.09it/s, train_loss=0.245]
# 100% 2/2 [00:00<00:00,  7.13it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0062 to 0.0061
# speechbrain.utils.train_logger - epoch: 43, lr: 6.18e-03 - train loss: 2.45e-01 - valid loss: 1.53e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-53+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-50+00
# speechbrain.utils.epoch_loop - Going into epoch 44
# 100% 10/10 [00:03<00:00,  3.02it/s, train_loss=0.211]
# 100% 2/2 [00:00<00:00,  6.31it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0061 to 0.006
# speechbrain.utils.train_logger - epoch: 44, lr: 6.09e-03 - train loss: 2.11e-01 - valid loss: 1.45e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-57+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-53+00
# speechbrain.utils.epoch_loop - Going into epoch 45
# 100% 10/10 [00:03<00:00,  2.62it/s, train_loss=0.199]
# 100% 2/2 [00:00<00:00,  6.05it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.006 to 0.0059
# speechbrain.utils.train_logger - epoch: 45, lr: 6.00e-03 - train loss: 1.99e-01 - valid loss: 1.17e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-01+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-56-57+00
# speechbrain.utils.epoch_loop - Going into epoch 46
# 100% 10/10 [00:03<00:00,  2.96it/s, train_loss=0.173]
# 100% 2/2 [00:00<00:00,  6.61it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0059 to 0.0058
# speechbrain.utils.train_logger - epoch: 46, lr: 5.91e-03 - train loss: 1.73e-01 - valid loss: 1.00e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-05+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-01+00
# speechbrain.utils.epoch_loop - Going into epoch 47
# 100% 10/10 [00:03<00:00,  3.03it/s, train_loss=0.154]
# 100% 2/2 [00:00<00:00,  7.12it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0058 to 0.0057
# speechbrain.utils.train_logger - epoch: 47, lr: 5.82e-03 - train loss: 1.54e-01 - valid loss: 9.23e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-09+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-05+00
# speechbrain.utils.epoch_loop - Going into epoch 48
# 100% 10/10 [00:03<00:00,  2.51it/s, train_loss=0.136]
# 100% 2/2 [00:00<00:00,  7.04it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0057 to 0.0056
# speechbrain.utils.train_logger - epoch: 48, lr: 5.73e-03 - train loss: 1.36e-01 - valid loss: 8.97e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-13+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-09+00
# speechbrain.utils.epoch_loop - Going into epoch 49
# 100% 10/10 [00:03<00:00,  3.25it/s, train_loss=0.133]
# 100% 2/2 [00:00<00:00,  7.05it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0056 to 0.0055
# speechbrain.utils.train_logger - epoch: 49, lr: 5.64e-03 - train loss: 1.33e-01 - valid loss: 7.59e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-17+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-13+00
# speechbrain.utils.epoch_loop - Going into epoch 50
# 100% 10/10 [00:03<00:00,  3.15it/s, train_loss=0.121]
# 100% 2/2 [00:00<00:00,  6.92it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0055 to 0.0055
# speechbrain.utils.train_logger - epoch: 50, lr: 5.55e-03 - train loss: 1.21e-01 - valid loss: 7.60e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-20+00
# speechbrain.utils.epoch_loop - Going into epoch 51
# 100% 10/10 [00:03<00:00,  2.68it/s, train_loss=0.11]
# 100% 2/2 [00:00<00:00,  4.24it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0055 to 0.0054
# speechbrain.utils.train_logger - epoch: 51, lr: 5.45e-03 - train loss: 1.10e-01 - valid loss: 6.44e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-25+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-20+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-17+00
# speechbrain.utils.epoch_loop - Going into epoch 52
# 100% 10/10 [00:03<00:00,  3.13it/s, train_loss=0.0994]
# 100% 2/2 [00:00<00:00,  6.75it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0054 to 0.0053
# speechbrain.utils.train_logger - epoch: 52, lr: 5.36e-03 - train loss: 9.94e-02 - valid loss: 5.47e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-29+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-25+00
# speechbrain.utils.epoch_loop - Going into epoch 53
# 100% 10/10 [00:03<00:00,  2.92it/s, train_loss=0.0917]
# 100% 2/2 [00:00<00:00,  6.25it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0053 to 0.0052
# speechbrain.utils.train_logger - epoch: 53, lr: 5.27e-03 - train loss: 9.17e-02 - valid loss: 5.43e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-32+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-29+00
# speechbrain.utils.epoch_loop - Going into epoch 54
# 100% 10/10 [00:03<00:00,  3.03it/s, train_loss=0.0861]
# 100% 2/2 [00:00<00:00,  4.49it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0052 to 0.0051
# speechbrain.utils.train_logger - epoch: 54, lr: 5.18e-03 - train loss: 8.61e-02 - valid loss: 5.19e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-36+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-32+00
# speechbrain.utils.epoch_loop - Going into epoch 55
# 100% 10/10 [00:03<00:00,  2.93it/s, train_loss=0.0797]
# 100% 2/2 [00:00<00:00,  6.72it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0051 to 0.005
# speechbrain.utils.train_logger - epoch: 55, lr: 5.09e-03 - train loss: 7.97e-02 - valid loss: 4.66e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-40+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-36+00
# speechbrain.utils.epoch_loop - Going into epoch 56
# 100% 10/10 [00:03<00:00,  2.81it/s, train_loss=0.0772]
# 100% 2/2 [00:00<00:00,  6.92it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.005 to 0.0049
# speechbrain.utils.train_logger - epoch: 56, lr: 5.00e-03 - train loss: 7.72e-02 - valid loss: 4.44e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-44+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-40+00
# speechbrain.utils.epoch_loop - Going into epoch 57
# 100% 10/10 [00:03<00:00,  3.16it/s, train_loss=0.0744]
# 100% 2/2 [00:00<00:00,  5.83it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0049 to 0.0048
# speechbrain.utils.train_logger - epoch: 57, lr: 4.91e-03 - train loss: 7.44e-02 - valid loss: 4.41e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-48+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-44+00
# speechbrain.utils.epoch_loop - Going into epoch 58
# 100% 10/10 [00:03<00:00,  2.53it/s, train_loss=0.0726]
# 100% 2/2 [00:00<00:00,  6.31it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0048 to 0.0047
# speechbrain.utils.train_logger - epoch: 58, lr: 4.82e-03 - train loss: 7.26e-02 - valid loss: 4.13e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-53+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-48+00
# speechbrain.utils.epoch_loop - Going into epoch 59
# 100% 10/10 [00:03<00:00,  3.00it/s, train_loss=0.067]
# 100% 2/2 [00:00<00:00,  6.59it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0047 to 0.0046
# speechbrain.utils.train_logger - epoch: 59, lr: 4.73e-03 - train loss: 6.70e-02 - valid loss: 4.62e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-56+00
# speechbrain.utils.epoch_loop - Going into epoch 60
# 100% 10/10 [00:02<00:00,  3.37it/s, train_loss=0.0663]
# 100% 2/2 [00:00<00:00,  6.52it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0046 to 0.0045
# speechbrain.utils.train_logger - epoch: 60, lr: 4.64e-03 - train loss: 6.63e-02 - valid loss: 4.10e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-00+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-56+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-57-53+00
# speechbrain.utils.epoch_loop - Going into epoch 61
# 100% 10/10 [00:04<00:00,  2.45it/s, train_loss=0.0668]
# 100% 2/2 [00:00<00:00,  6.39it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0045 to 0.0045
# speechbrain.utils.train_logger - epoch: 61, lr: 4.55e-03 - train loss: 6.68e-02 - valid loss: 3.71e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-04+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-00+00
# speechbrain.utils.epoch_loop - Going into epoch 62
# 100% 10/10 [00:03<00:00,  3.02it/s, train_loss=0.0622]
# 100% 2/2 [00:00<00:00,  6.20it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0045 to 0.0044
# speechbrain.utils.train_logger - epoch: 62, lr: 4.45e-03 - train loss: 6.22e-02 - valid loss: 3.49e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-08+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-04+00
# speechbrain.utils.epoch_loop - Going into epoch 63
# 100% 10/10 [00:03<00:00,  3.29it/s, train_loss=0.0586]
# 100% 2/2 [00:00<00:00,  6.97it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0044 to 0.0043
# speechbrain.utils.train_logger - epoch: 63, lr: 4.36e-03 - train loss: 5.86e-02 - valid loss: 3.52e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-12+00
# speechbrain.utils.epoch_loop - Going into epoch 64
# 100% 10/10 [00:03<00:00,  2.76it/s, train_loss=0.0619]
# 100% 2/2 [00:00<00:00,  4.27it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0043 to 0.0042
# speechbrain.utils.train_logger - epoch: 64, lr: 4.27e-03 - train loss: 6.19e-02 - valid loss: 3.63e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-16+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-12+00
# speechbrain.utils.epoch_loop - Going into epoch 65
# 100% 10/10 [00:03<00:00,  3.29it/s, train_loss=0.0569]
# 100% 2/2 [00:00<00:00,  6.74it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0042 to 0.0041
# speechbrain.utils.train_logger - epoch: 65, lr: 4.18e-03 - train loss: 5.69e-02 - valid loss: 3.54e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-20+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-16+00
# speechbrain.utils.epoch_loop - Going into epoch 66
# 100% 10/10 [00:03<00:00,  2.98it/s, train_loss=0.0553]
# 100% 2/2 [00:00<00:00,  6.67it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0041 to 0.004
# speechbrain.utils.train_logger - epoch: 66, lr: 4.09e-03 - train loss: 5.53e-02 - valid loss: 3.70e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-24+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-20+00
# speechbrain.utils.epoch_loop - Going into epoch 67
# 100% 10/10 [00:03<00:00,  2.96it/s, train_loss=0.0529]
# 100% 2/2 [00:00<00:00,  4.41it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.004 to 0.0039
# speechbrain.utils.train_logger - epoch: 67, lr: 4.00e-03 - train loss: 5.29e-02 - valid loss: 3.57e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-28+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-24+00
# speechbrain.utils.epoch_loop - Going into epoch 68
# 100% 10/10 [00:03<00:00,  2.91it/s, train_loss=0.0489]
# 100% 2/2 [00:00<00:00,  6.91it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0039 to 0.0038
# speechbrain.utils.train_logger - epoch: 68, lr: 3.91e-03 - train loss: 4.89e-02 - valid loss: 3.64e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-32+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-28+00
# speechbrain.utils.epoch_loop - Going into epoch 69
# 100% 10/10 [00:03<00:00,  3.21it/s, train_loss=0.052]
# 100% 2/2 [00:00<00:00,  6.12it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0038 to 0.0037
# speechbrain.utils.train_logger - epoch: 69, lr: 3.82e-03 - train loss: 5.20e-02 - valid loss: 3.39e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-36+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-08+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-32+00
# speechbrain.utils.epoch_loop - Going into epoch 70
# 100% 10/10 [00:03<00:00,  3.16it/s, train_loss=0.0489]
# 100% 2/2 [00:00<00:00,  4.36it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0037 to 0.0036
# speechbrain.utils.train_logger - epoch: 70, lr: 3.73e-03 - train loss: 4.89e-02 - valid loss: 3.87e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-40+00
# speechbrain.utils.epoch_loop - Going into epoch 71
# 100% 10/10 [00:03<00:00,  2.89it/s, train_loss=0.052]
# 100% 2/2 [00:00<00:00,  6.98it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0036 to 0.0035
# speechbrain.utils.train_logger - epoch: 71, lr: 3.64e-03 - train loss: 5.20e-02 - valid loss: 3.19e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-44+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-40+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-36+00
# speechbrain.utils.epoch_loop - Going into epoch 72
# 100% 10/10 [00:03<00:00,  2.75it/s, train_loss=0.0494]
# 100% 2/2 [00:00<00:00,  6.52it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0035 to 0.0035
# speechbrain.utils.train_logger - epoch: 72, lr: 3.55e-03 - train loss: 4.94e-02 - valid loss: 3.68e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-48+00
# speechbrain.utils.epoch_loop - Going into epoch 73
# 100% 10/10 [00:03<00:00,  3.16it/s, train_loss=0.0479]
# 100% 2/2 [00:00<00:00,  5.41it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0035 to 0.0034
# speechbrain.utils.train_logger - epoch: 73, lr: 3.45e-03 - train loss: 4.79e-02 - valid loss: 3.22e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-52+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-48+00
# speechbrain.utils.epoch_loop - Going into epoch 74
# 100% 10/10 [00:03<00:00,  2.78it/s, train_loss=0.0477]
# 100% 2/2 [00:00<00:00,  6.85it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0034 to 0.0033
# speechbrain.utils.train_logger - epoch: 74, lr: 3.36e-03 - train loss: 4.77e-02 - valid loss: 3.06e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-56+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-52+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-44+00
# speechbrain.utils.epoch_loop - Going into epoch 75
# 100% 10/10 [00:03<00:00,  3.20it/s, train_loss=0.047]
# 100% 2/2 [00:00<00:00,  6.85it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0033 to 0.0032
# speechbrain.utils.train_logger - epoch: 75, lr: 3.27e-03 - train loss: 4.70e-02 - valid loss: 3.38e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-00+00
# speechbrain.utils.epoch_loop - Going into epoch 76
# 100% 10/10 [00:03<00:00,  3.30it/s, train_loss=0.0442]
# 100% 2/2 [00:00<00:00,  7.07it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0032 to 0.0031
# speechbrain.utils.train_logger - epoch: 76, lr: 3.18e-03 - train loss: 4.42e-02 - valid loss: 2.86e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-03+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-58-56+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-00+00
# speechbrain.utils.epoch_loop - Going into epoch 77
# 100% 10/10 [00:03<00:00,  2.57it/s, train_loss=0.0447]
# 100% 2/2 [00:00<00:00,  6.82it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0031 to 0.003
# speechbrain.utils.train_logger - epoch: 77, lr: 3.09e-03 - train loss: 4.47e-02 - valid loss: 3.01e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-08+00
# speechbrain.utils.epoch_loop - Going into epoch 78
# 100% 10/10 [00:03<00:00,  3.22it/s, train_loss=0.0478]
# 100% 2/2 [00:00<00:00,  6.81it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.003 to 0.0029
# speechbrain.utils.train_logger - epoch: 78, lr: 3.00e-03 - train loss: 4.78e-02 - valid loss: 2.87e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-12+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-08+00
# speechbrain.utils.epoch_loop - Going into epoch 79
# 100% 10/10 [00:03<00:00,  3.15it/s, train_loss=0.0418]
# 100% 2/2 [00:00<00:00,  6.98it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0029 to 0.0028
# speechbrain.utils.train_logger - epoch: 79, lr: 2.91e-03 - train loss: 4.18e-02 - valid loss: 2.80e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-15+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-12+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-03+00
# speechbrain.utils.epoch_loop - Going into epoch 80
# 100% 10/10 [00:03<00:00,  2.63it/s, train_loss=0.0413]
# 100% 2/2 [00:00<00:00,  6.09it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0028 to 0.0027
# speechbrain.utils.train_logger - epoch: 80, lr: 2.82e-03 - train loss: 4.13e-02 - valid loss: 3.03e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-20+00
# speechbrain.utils.epoch_loop - Going into epoch 81
# 100% 10/10 [00:02<00:00,  3.41it/s, train_loss=0.0443]
# 100% 2/2 [00:00<00:00,  6.66it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0027 to 0.0026
# speechbrain.utils.train_logger - epoch: 81, lr: 2.73e-03 - train loss: 4.43e-02 - valid loss: 2.84e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-23+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-20+00
# speechbrain.utils.epoch_loop - Going into epoch 82
# 100% 10/10 [00:02<00:00,  3.51it/s, train_loss=0.0419]
# 100% 2/2 [00:00<00:00,  6.88it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0026 to 0.0025
# speechbrain.utils.train_logger - epoch: 82, lr: 2.64e-03 - train loss: 4.19e-02 - valid loss: 2.70e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-27+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-15+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-23+00
# speechbrain.utils.epoch_loop - Going into epoch 83
# 100% 10/10 [00:03<00:00,  2.93it/s, train_loss=0.0425]
# 100% 2/2 [00:00<00:00,  4.50it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0025 to 0.0025
# speechbrain.utils.train_logger - epoch: 83, lr: 2.55e-03 - train loss: 4.25e-02 - valid loss: 3.10e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-31+00
# speechbrain.utils.epoch_loop - Going into epoch 84
# 100% 10/10 [00:03<00:00,  2.97it/s, train_loss=0.0422]
# 100% 2/2 [00:00<00:00,  6.93it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0025 to 0.0024
# speechbrain.utils.train_logger - epoch: 84, lr: 2.45e-03 - train loss: 4.22e-02 - valid loss: 3.29e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-35+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-31+00
# speechbrain.utils.epoch_loop - Going into epoch 85
# 100% 10/10 [00:03<00:00,  3.08it/s, train_loss=0.0407]
# 100% 2/2 [00:00<00:00,  6.41it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0024 to 0.0023
# speechbrain.utils.train_logger - epoch: 85, lr: 2.36e-03 - train loss: 4.07e-02 - valid loss: 3.11e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-39+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/Transformer/1986/save/CKPT+2024-02-18+22-59-35+00
# ...
# HYP: WHEN IT RECEIVED TELEGRAPHED NEWS FROM IRELAND
# --------
# snt135
# REF: I WISH I'D SEEN HIM SAID COULSON
# HYP: I WISH I'D SEEN HIM SAID COULSON
# --------
# snt118
# REF: CONSEIL I CALLED A THIRD TIME CONSEIL APPEARED
# HYP: CONSEIL I CALLED A THIRD TIME CONSEIL APPEARED
# --------
# snt18
# REF: AND THEN THE OFFICIAL LETTER FROM LONDON WAS READ TO THEM
# HYP: AND THEN THE OFFICIAL LETTER FROM LONDON WAS READ TO THEM
# --------
# snt139
# REF: THE STRONGHOLD OF THE GREAT WEST
# HYP: THE STRONGHOLD OF THE GREAT WEST
# --------
# snt100
# REF: THE NEW AGE WAS I THINK THE PIONEER IN THE MATTER
# HYP: THE NEW AGE WAS I THINK THE PIONEER IN THE MATTER
# --------
# snt26
# REF: IN COUNTRY TOWNS WHEN GIRLS ARE WALKING WITH YOUNG MEN
# HYP: IN COUNTRY TOWNS WHEN GIRLS ARE WALKING WITH YOUNG MEN
# --------
# snt154
# REF: AND THE GREAT BLUE HILL FLOATS ABOVE THEM ALL
# HYP: AND THE GREAT BLUE HILL FLOATS ABOVE THEM ALL
# --------
# snt15
# REF: AND HAS NO DUPLICATE IN ALL THE KNOWN WORLD
# HYP: AND HAS NO DUPLICATE IN ALL THE KNOWN WORLD
# --------
# snt149
# REF: AM I A WHAT HE DEMANDED
# HYP: AM I A WHAT HE DEMANDED
# --------
# snt176
# REF: HUMAN BEINGS AND WHAT THEY WANT AND DO
# HYP: HUMAN BEINGS AND WHAT THEY WANT AND DO
# --------
# snt163
# --------
# snt65
# REF: WITH A BRANDY BOTTLE UNDER HER APRON STEALING UP STAIRS
# HYP: WITH A BRANDY BOTTLE UNDER HER APRON STEALING UP STAIRS
# --------
# snt183
# REF: A MISSUS MERCY SMITH BECKONED TO ME TO COME TO HER CLASS
# HYP: A MISSUS MERCY SMITH BECKONED TO ME TO COME TO HER CLASS
# --------
# snt153
# REF: AND I SHALL BECOME QUITE WELL AGAIN AS BEFORE AT FIRST
# HYP: AND I SHALL BECOME QUITE WELL AGAIN AS BEFORE AT FIRST
# --------
# snt2
# REF: AS HE RECALLED SUCHET'S SAYING AT SARAGOSSA
# HYP: AS HE RECALLED SUCHET'S SAYING AT SARAGOSSA
# --------
# snt71
# REF: AND DRESSED IN AN OLD STABLE SUIT OF CLOTHES THE PEASANT
# HYP: AND DRESSED IN AN OLD STABLE SUIT OF CLOTHES THE PEASANT
# --------
# snt8
# REF: AND HOW MIGHT YOU LEARN BY ACCIDENT OR ARGUMENT
# HYP: AND HOW MIGHT YOU LEARN BY ACIIDENT OR ARGUMENT
# --------
# snt53
# REF: WITH THE DIGNITY OF A MONARCH AND THE AIR OF A FATHER
# HYP: WITH THE DIGNITY OF A MONARCH AND THE AIR OF A FATHER
# --------
# snt54
# REF: AND THE WHOLE OF NEW BRUNSWICK WERE OCCUPIED
# HYP: AND THE WHOLE OF NEW BRUNSWICK WERE OCUUPIED
# --------
# snt109
# REF: HE LOVED TO HAVE THE CLOTH LAID
# HYP: HE LOVED TO HAVE THE CLOTH LAID
# --------
# snt136
# REF: TERESA WAS SIXTEEN AND VAMPA SEVENTEEN
# HYP: TERESA WAS SIXTEEN AND VAMPA SEVENTEEN
# --------
# snt152
# REF: HIS HEART ACTION IS PRETTY WEAK EVEN YET
# HYP: HIS HEART ACTION IS PRETTY WEAK EVEN YET
# --------
# snt103
# REF: GEE GEE THE FROG HOPPED SEVERAL TIMES
# HYP: GEE GEE THE FROG HOPPED SEVERAL TIMES
# --------
# 100% 2/2 [00:00<00:00,  5.42it/s]
# speechbrain.utils.train_logger - Epoch loaded: 100 - test loss: 1.44e-02

# %% [markdown]
# Also in this case, you should see that the best model provides reasonable predictions:

# %% [markdown]
# ```
# epoch: 1, lr: 1.00e-02 - train loss: 2.95 - valid loss: 2.70
# epoch: 2, lr: 9.91e-03 - train loss: 2.59 - valid loss: 2.50
# epoch: 3, lr: 9.82e-03 - train loss: 2.48 - valid loss: 2.45
# epoch: 4, lr: 9.73e-03 - train loss: 2.42 - valid loss: 2.41
# epoch: 5, lr: 9.64e-03 - train loss: 2.38 - valid loss: 2.37
# epoch: 6, lr: 9.55e-03 - train loss: 2.34 - valid loss: 2.32
# epoch: 7, lr: 9.45e-03 - train loss: 2.30 - valid loss: 2.30
# epoch: 8, lr: 9.36e-03 - train loss: 2.25 - valid loss: 2.25
# epoch: 9, lr: 9.27e-03 - train loss: 2.22 - valid loss: 2.21
# epoch: 10, lr: 9.18e-03 - train loss: 2.16 - valid loss: 2.14
# epoch: 11, lr: 9.09e-03 - train loss: 2.08 - valid loss: 2.03
# epoch: 12, lr: 9.00e-03 - train loss: 1.98 - valid loss: 1.88
# epoch: 80, lr: 2.82e-03 - train loss: 3.33e-02 - valid loss: 2.48e-02
# epoch: 81, lr: 2.73e-03 - train loss: 3.33e-02 - valid loss: 2.53e-02
# epoch: 82, lr: 2.64e-03 - train loss: 3.07e-02 - valid loss: 2.54e-02
# epoch: 83, lr: 2.55e-03 - train loss: 3.13e-02 - valid loss: 2.48e-02
# epoch: 84, lr: 2.45e-03 - train loss: 3.02e-02 - valid loss: 2.44e-02
# epoch: 85, lr: 2.36e-03 - train loss: 3.25e-02 - valid loss: 2.30e-02
# epoch: 86, lr: 2.27e-03 - train loss: 2.88e-02 - valid loss: 2.26e-02
# epoch: 87, lr: 2.18e-03 - train loss: 2.86e-02 - valid loss: 2.35e-02
# epoch: 88, lr: 2.09e-03 - train loss: 2.84e-02 - valid loss: 2.20e-02
# epoch: 89, lr: 2.00e-03 - train loss: 2.56e-02 - valid loss: 2.11e-02
# epoch: 90, lr: 1.91e-03 - train loss: 2.52e-02 - valid loss: 2.14e-02
# epoch: 91, lr: 1.82e-03 - train loss: 2.61e-02 - valid loss: 2.21e-02
# epoch: 92, lr: 1.73e-03 - train loss: 2.42e-02 - valid loss: 2.07e-02
# epoch: 93, lr: 1.64e-03 - train loss: 2.54e-02 - valid loss: 2.06e-02
# epoch: 94, lr: 1.55e-03 - train loss: 2.52e-02 - valid loss: 2.13e-02
# epoch: 95, lr: 1.45e-03 - train loss: 2.34e-02 - valid loss: 2.19e-02
# epoch: 96, lr: 1.36e-03 - train loss: 2.39e-02 - valid loss: 2.15e-02
# epoch: 97, lr: 1.27e-03 - train loss: 2.18e-02 - valid loss: 2.17e-02
# epoch: 98, lr: 1.18e-03 - train loss: 2.19e-02 - valid loss: 2.20e-02
# epoch: 99, lr: 1.09e-03 - train loss: 2.12e-02 - valid loss: 2.08e-02
# epoch: 100, lr: 1.00e-03 - train loss: 2.13e-02 - valid loss: 1.93e-02
# Epoch loaded: 100 - test loss: 1.15e-02
# ```

# %% [markdown]
# Note that variations to the performance are expected. The most important thing is to get a good test loss (e.g., < 2.50e-02).

# %% [markdown]
# **Complete the code below** to plot the Transformer validation losses.

# %%
import matplotlib.pyplot as plt

def get_losses(log_file):
  """This function takes in input a path of a log-file and outputs the train and
  valid losses in lists of float numbers"""

  # Your code here. Aim for 9-10 lines
  with open(log_file) as f:
      train_losses = []
      valid_losses =[]
      for line in f:
          if 'train loss' in line:
            train_loss = float(line.split('train loss: ')[1].split(' ')[0])
            train_losses.append(train_loss)
          if 'valid loss' in line:
            valid_loss = float(line.split('valid loss: ')[1])
            valid_losses.append(valid_loss)
      return train_losses, valid_losses


Transformer_log_file = 'results/Transformer/1986/train_log.txt'

# Your code here. Aim for 1 line.
_ , Transformer_valid_losses = get_losses(Transformer_log_file)


plt.plot(Transformer_valid_losses, label='Tranformers')
plt.ylabel('Loss')
plt.xlabel('# Epochs')
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You can now compare the results that you achieved with the Transformer with the ones achieved last lab with RNNs. You should see better test peformance with the Transformer-based model.
#
#
# Thanks to your precious contribution, the world now knows how to translate from Ignotush to English. Your work will allow historians and archeologists better understand this ancient civilization.
