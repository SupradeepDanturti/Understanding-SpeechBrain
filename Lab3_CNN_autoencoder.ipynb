# %% [markdown]
# # **Week 3: Lab Exercises for COMP499/691 Conversational AI**

# %% [markdown]
# The goal of this lab is to familiarize yourself with **Convolutional Neural Networks** (CNNs).
#
# In this lab, you will implement a **convolutional autoencoder** with [SpeechBrain](https://speechbrain.github.io/).
#
# An [autoencoder](https://en.wikipedia.org/wiki/Autoencoder) is a neural network that attempts to predict the inputs itself.
#
# Without adding anything special, the task would be very trivial. The network can copy and paste the output using a simple identity function. To make the task more meaningful, we add a **bottleneck** in the architecture. The bottleneck compresses the information such that identity mapping is not possible, and we thus force the model to learn a meaningful compressed representation of the input.
#
#
# The autoencoder is composed of an **encoder** and a **decoder**. The encoder turns the input into a compressed representation (bottleneck). The decoder, instead, attempts to reconstruct the original signal on top of the compressed representation.
#
# Such an architecture is suitable for feature learning. If the encoder is well designed, we should learn some useful representation in the output. We will use this representation as input features for an audio digit classifier.
#
#
# As in the previous lab, we will work with the [audio MNIST dataset](https://www.kaggle.com/datasets/alanchn31/free-spoken-digits).

# %% [markdown]
# **Run the code below** to install SpeechBrain:

# %%
# %%capture
# !pip install speechbrain

# %% [markdown]
# If everything works well, you should be able to import speechbrain like this:

# %%
import speechbrain

# %% [markdown]
# Let's also import some libraries that will be useful later:

# %%
import torch
import torchaudio
import matplotlib.pyplot as plt
from IPython.display import Audio
torch.manual_seed(2023)

# %% [markdown]
# **Run the code below** to download the audio MNIST dataset. The dataset is quite big (downloading it might take a few minutes).

# %%
# !git clone https://github.com/soerenab/AudioMNIST /content/AudioMNIST
# Out:
# Cloning into '/content/AudioMNIST'...
# remote: Enumerating objects: 30128, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 30128 (delta 3), reused 0 (delta 0), pack-reused 30119
# Receiving objects: 100% (30128/30128), 944.54 MiB | 19.76 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# Updating files: 100% (30018/30018), done.

# %% [markdown]
# ##**Exercise 1 - Data Preparation**
#
# The goal is to create the data manifest files (in CSV format) that SpeechBrain expects in input. These files tell SpeechBrain where to find the speech data and their corresponding labels for the training, validation, and test sets.
#
# You have to create 3 JSON files (`tran.json`, `valid.json`, `test.json`) structured in this way:
#
#
# ```
# {
#   "6_10_30.wav": {
#     "wav": "AudioMNIST/data/10/6_10_30.wav",
#     "length": 0.7466041666666666,
#     "digit": "6"
#   },
#   "4_10_22.wav": {
#     "wav": "AudioMNIST/data/10/4_10_22.wav",
#     "length": 0.6258125,
#     "digit": "4"
#   },
#   ........
# ```
#
#
# In particular, we split the dataset in this way:
# - `training` with speakers from 1 to 10.
# - `validation` with speakers from 11 to 14.
# - `test` with speakers from 15 to 18.
#
# Note that we are using only a portion of the dataset to make training faster.
#
# **This step is the same as the previous lab. You can copy and paste the code from the previous lab if you have done it.**

# %% [markdown]
# **Write the code for the AudioMNIST data preparation**.

# %%
# Your code here.
import json
from speechbrain.utils.data_utils import get_all_files

audiofiles = get_all_files("AudioMNIST/data", match_and = ".wav")

train_speakers = ['/01/','/02/','/03/','/04/','/05/','/06/','/07/','/08/','/09/','/10/']
valid_speakers = ['/11/','/12/','/13/','/14/']
test_speakers = ['/15/','/16/','/17/','/18/']

def split_data(audiofiles, spks):
  """This function takes in input a list of audio files and returns a list
  containing only files from the given list of speakers."""
  # Your code here. Aim for 5-6 lines
  return list(filter(lambda x: any(spk in x for spk in spks), audiofiles))



# Splitting data
train_files = split_data(audiofiles, train_speakers)
valid_files = split_data(audiofiles, valid_speakers)
test_files = split_data(audiofiles, test_speakers)

print(len(train_files))
print(len(valid_files))
print(len(test_files))


def create_json(json_file, audiolist):
  json_dict = {}
  for audiofile in audiolist:

    # Getting info
    audioinfo = torchaudio.info(audiofile)
    # Compute the duration in seconds.
    # This is the number of samples divided by the sampling frequency
    duration =  audioinfo.num_frames / audioinfo.sample_rate

    digit = audiofile.split('/')[3].split('_')[0]

    # Get a unique utterance id
    uttid = audiofile.split('/')[3]

    # Create entry for this utterance
    json_dict[uttid] = {
            "wav": audiofile,
            "length": duration,
            "digit": digit,
    }

    # Writing the dictionary to the json file
    with open(json_file, mode="w") as json_f:
      json.dump(json_dict, json_f, indent=2)
# Creating JSON files
create_json('train.json', train_files)
create_json('valid.json', valid_files)
create_json('test.json', test_files)
# Out:
# 5000
# 2000
# 2000

# %% [markdown]
# ###**Exercise 2 - Convolutional Autoencoder**
#
# In this exercise, you will implement a convolutional autoencoder. In particular, we ask you to implement the following model:

# %% [markdown]
# ![pictures-Page-1.drawio.png](data:image/png;base64,...)

# %% [markdown]
# In the figure, we also report an example of the expected dimensionalities. The last dimensionality is the time that will change from batch to batch.
#
# The **encoder** should have the following architecture:

# %% [markdown]
# ![pictures-Page-6.drawio.png](data:image/png;base64,...)

# %% [markdown]
# The encoder is composed of three strided convolutions that downsample the time dimension to a factor of 160 (at 16 kHz, this corresponds to having a feature every 10 ms of speech signal). We also use *Leaky ReLU* activations and dropout for regularization.
#
# Use the models defined in `torch.nn` to implement it.
# In the brackets you find the hyperparameters to use (in the order in which they appear in the PyTorch documentation).
#
# The **decoder** has the following architecture:

# %% [markdown]
# ![pictures-Page-6.drawio (1).png](data:image/png;base64,...)

# %% [markdown]
# The decoder upsamples the features by a factor of 160 using three transposed convolutions. Dropout and leaky ReLU are used as well. The output of the decoder attempts to predict the original audio signal.
#
# Use the models defined in torch.nn to implement it.
# In the brackets, you find the hyperparameters to use (in the order in which they appear in the PyTorch documentation).

# %% [markdown]
# **Complete the code below** to implement the desired autoencoder.

# %%
# %%file models.py

import torch
from torch import nn
from torch.nn import Conv1d, ConvTranspose1d, LayerNorm, Sequential, Dropout, LeakyReLU

class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        # Your code here. Aim for 8-9 lines.
        # Suggestion: Use the torch.nn sequential container.
        self.Sequential1 = nn.Sequential(
            nn.Conv1d(1, 10, 17, 2, 8),
            nn.LeakyReLU(),
            nn.Dropout(0.2),
            nn.Conv1d(10, 5, 9, 8, 4),
            nn.LeakyReLU(),
            nn.Dropout(0.2),
            nn.Conv1d(5, 40, 5, 10, 2),
          )

    def forward(self, x):
        # Your code here. Aim for 1-2 lines.
        out = self.Sequential1(x)
        return out


class Decoder(nn.Module):
    def __init__(self, inp_channels=40):
        super().__init__()
        # Your code here. Aim for 9-10 lines.
        # Suggestion: Use the torch.nn sequential container.
        self.Sequential2 = nn.Sequential(
            nn.LeakyReLU(),
            nn.ConvTranspose1d(40, 5, 5, 10, 2, 9),
            nn.LeakyReLU(),
            nn.Dropout(0.2),
            nn.ConvTranspose1d(5, 10, 9, 8, 4, 7),
            nn.LeakyReLU(),
            nn.Dropout(0.2),
            nn.ConvTranspose1d(10, 1, 17, 2, 8, 1),
          )


    def forward(self, x):
        # Your code here. Aim for 1-2 lines.
        out = self.Sequential2(x)
        return out
# Out:
# Writing models.py

# %% [markdown]
# **Run the code below** to test your model.

# %%
# Importing the library from the file.
# This is reloaded every time to allow modifications of library file.
import importlib
import models
importlib.reload(models)
from models import Encoder, Decoder

# Initialization
encoder = Encoder()
decoder = Decoder()

# Using the encoder and decoder
input = torch.rand(4, 1, 8000)
print(input.shape)

enc_output = encoder(input)
dec_output = decoder(enc_output)
print(enc_output.shape)
print(dec_output.shape)
# Out:
# torch.Size([4, 1, 8000])
# torch.Size([4, 40, 50])
# torch.Size([4, 1, 8000])

# %% [markdown]
# If everything works well, you should obtain the following dimensionalities:
#
#
#
# ```
# torch.Size([4, 1, 8000])
# torch.Size([4, 40, 50])
# torch.Size([4, 1, 8000])
# ```

# %% [markdown]
# Now, we can train the model using SpeechBrain.
#
# **Run the code below** to import and store the YAML file for hyperparameter specification.

# %%
# %%file hparams_autoencoder.yaml
#
# # #################################
# # Training a Convolutional Autoencoder
# # #################################
#
# # Seed needs to be set at top of yaml, before objects with parameters are made
# seed: 1986
# __set_seed: !!python/object/apply:torch.manual_seed [!ref <seed>]
#
# output_folder: !ref ./results/AudioMNIST/Autoencoder/<seed>
# save_folder: !ref <output_folder>/save
# train_log: !ref <output_folder>/train_log.txt
#
# # Path where data manifest files are stored
# train_annotation: train.json
# valid_annotation: valid.json
# test_annotation: test.json
#
# # The train logger writes training statistics to a file, as well as stdout.
# train_logger: !new:speechbrain.utils.train_logger.FileTrainLogger
#     save_file: !ref <train_log>
#
#
# # Training Parameters
# number_of_epochs: 20
# batch_size: 64
# lr_start: 0.002
# lr_final: 0.0002
#
# dataloader_options:
#     batch_size: !ref <batch_size>
#
#
# # Encoder
# encoder: !new:models.Encoder
#
# # Decoder
# decoder: !new:models.Decoder
#
#
# # The first object passed to the Brain class is this "Epoch Counter"
# # which is saved by the Checkpointer so that training can be resumed
# # if it gets interrupted at any point.
# epoch_counter: !new:speechbrain.utils.epoch_loop.EpochCounter
#     limit: !ref <number_of_epochs>
#
# # Objects in "modules" dict will have their parameters moved to the correct
# # device, as well as having train()/eval() called on them by the Brain class.
# modules:
#     encoder: !ref <encoder>
#     decoder: !ref <decoder>
#
# # This optimizer will be constructed by the Brain class after all parameters
# # are moved to the correct device. Then it will be added to the checkpointer.
# opt_class: !name:torch.optim.Adam
#     lr: !ref <lr_start>
#
# # This function manages learning rate annealing over the epochs.
# # We here use the simple lr annealing method that linearly decreases
# # the lr from the initial value to the final one.
# lr_annealing: !new:speechbrain.nnet.schedulers.LinearScheduler
#     initial_value: !ref <lr_start>
#     final_value: !ref <lr_final>
#     epoch_count: !ref <number_of_epochs>
#
# # This object is used for saving the state of training both so that it
# # can be resumed if it gets interrupted, and also so that the best checkpoint
# # can be later loaded for evaluation or inference.
# checkpointer: !new:speechbrain.utils.checkpoints.Checkpointer
#     checkpoints_dir: !ref <save_folder>
#     recoverables:
#         encoder: !ref <encoder>
#         decoder: !ref <decoder>
#         counter: !ref <epoch_counter>
# Out:
# Writing hparams_autoencoder.yaml

# %% [markdown]
# Now, we need to work on the training script itself (train.py).
#
# **Complete the code below** and start training a model. In particular, you should write your code for the `compute_foward` and `compute objective` methods. Moreover, you have to complete the code in the `audio_pipeline` function and add the resampling function to downsample the signal to 16 kHz. You can use `torchaudio.functional.resample` (make sure the dimensionality of the returned signal matches with the expected format: `[batch, time]`). You can draw inspiration from the previous lab session.

# %%
# %%file train.py

#!/usr/bin/env python3
"""Recipe for training a convolutional autoencoder with audioMNIST

To run this recipe, do the following:
> python train.py hparams.yaml

"""

import os
import sys
import torch
import torchaudio
from hyperpyyaml import load_hyperpyyaml
from speechbrain.utils.distributed import run_on_main
import speechbrain as sb



# Brain class for signal reconstruction training
class SignalReconstructionBrain(sb.Brain):
    def compute_forward(self, batch, stage):
        """Runs all the computations that transform the input into the output.
        Arguments
        ---------
        batch : PaddedBatch
            This batch object contains all the relevant tensors for computation.
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, or sb.Stage.TEST.
        Returns
        -------
        predictions : Tensor
            Tensor that contains the predicted signal.
        """
        # We first move the batch to the appropriate device.
        batch = batch.to(self.device)
        wavs, lens = batch.sig

        # Your code here. Aim for 3-4 lines.
        # Warning: SpeechBrain returns tensors in the format [batch, time], while
        # the convolutional autoencoder expects [batch, inp_channels, time].
        # You need to transpose properly the input and the output.

        wavs = wavs.unsqueeze(1)
        features = self.modules.encoder(wavs)
        predictions = self.modules.decoder(features)
        predictions = predictions.squeeze(1)
        # # torch.Size([64, 11727])
        # torch.Size([64, 1, 11727])wavs.unsqueeze(1)
        # torch.Size([64, 40, 74])
        # torch.Size([64, 40, 74])
        # torch.Size([64, 1, 11840])
        # torch.Size([64, 11840])
      #   tensor([[ 0.0074, -0.0269, -0.0031,  ..., -0.0781,  0.0711, -0.0674],
      #   [-0.0033,  0.0193,  0.0278,  ..., -0.0893,  0.0693, -0.0360],
      #   [ 0.0019,  0.0168,  0.0645,  ..., -0.0954,  0.0449, -0.0374],
      #   ...,
      #   [ 0.0044, -0.0362,  0.0411,  ..., -0.0464,  0.0024, -0.0826],
      #   [ 0.0077, -0.0289,  0.0270,  ..., -0.0528,  0.0833, -0.0817],
      #   [ 0.0313, -0.0327,  0.0564,  ..., -0.0482,  0.0654, -0.0678]],
      #  device='cuda:0', grad_fn=<SqueezeBackward1>)

        # At test time, we store the samples into the output folder.
        # This way we can listen to the reconstructed samples.
        if stage == sb.Stage.TEST:
          save_path = self.hparams.output_folder+'/samples/'
          if not os.path.exists(save_path):
            os.makedirs(save_path)
          for i, id in enumerate(batch.id):
            save_file = save_path + id
            torchaudio.save(save_file, predictions[i].cpu().unsqueeze(0),16000)
            torchaudio.save(save_file.replace('.wav','_original.wav'), wavs[i].cpu(),16000)


        return predictions


    def compute_objectives(self, predictions, batch, stage):
        """Computes the loss given the predicted and targeted outputs.
        Arguments
        ---------
        predictions : tensor
            The output tensor from `compute_forward`.
        batch : PaddedBatch
            This batch object contains all the relevant tensors for computation.
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, or sb.Stage.TEST.
        Returns
        -------
        loss : torch.Tensor
            A one-element tensor used for backpropagating the gradient.
        """
        label, lens = batch.sig
        # Cut predictions to match the label dimensionality.
        predictions = predictions[:,0:label.shape[1]]

        # Loss computation.
        # Your code here. Aim for 1 line
        loss = sb.nnet.losses.mse_loss(predictions, label, lens)
        # Append this batch of losses to the loss metric for easy
        self.loss_metric.append(
            batch.id, predictions, label, lens, reduction="batch"
        )

        return loss

    def on_stage_start(self, stage, epoch=None):
        """Gets called at the beginning of each epoch.
        Arguments
        ---------
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, or sb.Stage.TEST.
        epoch : int
            The currently-starting epoch. This is passed
            `None` during the test stage.
        """
        # Set up statistics trackers for this stage
        self.loss_metric = sb.utils.metric_stats.MetricStats(
            metric=sb.nnet.losses.mse_loss
        )

    def on_stage_end(self, stage, stage_loss, epoch=None):
        """Gets called at the end of an epoch.
        Arguments
        ---------
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, sb.Stage.TEST
        stage_loss : float
            The average loss for all of the dataset processed in this stage.
        epoch : int
            The currently-starting epoch. This is passed
            `None` during the test stage.
        """
        # Store the train loss until the validation stage.
        if stage == sb.Stage.TRAIN:
            self.train_loss = stage_loss

        # Summarize the statistics from the stage for record-keeping.
        else:
            stats = {
                "loss": stage_loss,
            }

        # At the end of validation...
        if stage == sb.Stage.VALID:

            old_lr, new_lr = self.hparams.lr_annealing(epoch)
            sb.nnet.schedulers.update_learning_rate(self.optimizer, new_lr)

            # The train_logger writes a summary to stdout and to the logfile.
            self.hparams.train_logger.log_stats(
                {"Epoch": epoch, "lr": old_lr},
                train_stats={"loss": self.train_loss},
                valid_stats=stats,
            )

            # Save the current checkpoint and delete previous checkpoints,
            self.checkpointer.save_and_keep_only(meta=stats, min_keys=["error"])

        # We also write statistics about test dataset to stdout and to the logfile.
        if stage == sb.Stage.TEST:
            self.hparams.train_logger.log_stats(
                {"Epoch loaded": self.hparams.epoch_counter.current},
                test_stats=stats,
            )


def dataio_prep(hparams):
    """This function prepares the datasets to be used in the brain class.
    It also defines the dataset processing pipeline through user-defined functions.
    Arguments
    ---------
    hparams : dict
        This dictionary is loaded from the `hparams.yaml` file, and it includes
        all the hyperparameters needed for dataset construction and loading.
    Returns
    -------
    datasets : dict
        Contains three keys, "train", "valid" and "test" that correspond
        to the appropriate DynamicItemDataset object.
    """
    # Define audio pipeline
    @sb.utils.data_pipeline.takes("wav")
    @sb.utils.data_pipeline.provides("sig")
    def audio_pipeline(wav):
        """Load the signal, and pass it and its length to the corruption class.
        This is done on the CPU in the `collate_fn`."""
        # Your code here. Aim for 3-4 lines. Call the audio tensor "sig"
        sig, fs = torchaudio.load(wav)
        sig = torchaudio.functional.resample(sig, fs, 16000).squeeze(0)
        # We normalize the waveform to be between 0 and 1.
        sig = sig/sig.abs().max()
        return sig

    # Define datasets. We also connect the dataset with the dataset processing
    # functions defined above.
    datasets = {}
    data_info = {
        "train": hparams["train_annotation"],
        "valid": hparams["valid_annotation"],
        "test": hparams["test_annotation"],
    }
    hparams["dataloader_options"]["shuffle"] = False
    for dataset in data_info:
        datasets[dataset] = sb.dataio.dataset.DynamicItemDataset.from_json(
            json_path=data_info[dataset],
            dynamic_items=[audio_pipeline],
            output_keys=["id", "sig"],
        )

    return datasets


# Recipe begins!
if __name__ == "__main__":
    # Reading command line arguments.
    hparams_file, run_opts, overrides = sb.parse_arguments(sys.argv[1:])

    # Initialize ddp (useful only for multi-GPU DDP training).
    sb.utils.distributed.ddp_init_group(run_opts)

    # Load hyperparameters file with command-line overrides.
    with open(hparams_file) as fin:
        hparams = load_hyperpyyaml(fin, overrides)

    # Create experiment directory
    sb.create_experiment_directory(
        experiment_directory=hparams["output_folder"],
        hyperparams_to_save=hparams_file,
        overrides=overrides,
    )

    # Create dataset objects "train", "valid", and "test".
    datasets = dataio_prep(hparams)

    # Initialize the Brain object to prepare for mask training.
    brain = SignalReconstructionBrain(
        modules=hparams["modules"],
        opt_class=hparams["opt_class"],
        hparams=hparams,
        run_opts=run_opts,
        checkpointer=hparams["checkpointer"],
    )

    # The `fit()` method iterates the training loop, calling the methods
    # necessary to update the parameters of the model. Since all objects
    # with changing state are managed by the Checkpointer, training can be
    # stopped at any point, and will be resumed on next call.
    brain.fit(
        epoch_counter=brain.hparams.epoch_counter,
        train_set=datasets["train"],
        valid_set=datasets["valid"],
        train_loader_kwargs=hparams["dataloader_options"],
        valid_loader_kwargs=hparams["dataloader_options"],
    )

    # Load the best checkpoint for evaluation
    test_stats = brain.evaluate(
        test_set=datasets["test"],
        min_key="error",
        test_loader_kwargs=hparams["dataloader_options"],
    )
# Out:
# Writing train.py

# %% [markdown]
# **Run the code below** to train the model.

# %%
# To start from scratch, you need to remove the output folder.
# Otherwise, speechbrain starts from the last valid checkpoint.
#!rm -rf ./results/AudioMNIST/Autoencoder/

# !python train.py hparams_autoencoder.yaml
# Out:
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: ./results/AudioMNIST/Autoencoder/1986
# speechbrain.core - 3.3k trainable parameters in SignalReconstructionBrain
# speechbrain.utils.checkpoints - Would load a checkpoint here, but none found yet.
# speechbrain.utils.epoch_loop - Going into epoch 1
# 100% 79/79 [00:43<00:00,  1.82it/s, train_loss=0.0292]
# 100% 32/32 [00:17<00:00,  1.79it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.002 to 0.0019
# speechbrain.utils.train_logger - Epoch: 1, lr: 2.00e-03 - train loss: 2.92e-02 - valid loss: 2.48e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-21-26+00
# speechbrain.utils.epoch_loop - Going into epoch 2
# 100% 79/79 [00:41<00:00,  1.91it/s, train_loss=0.0229]
# 100% 32/32 [00:17<00:00,  1.86it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0019 to 0.0018
# speechbrain.utils.train_logger - Epoch: 2, lr: 1.91e-03 - train loss: 2.29e-02 - valid loss: 2.34e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-22-24+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-21-26+00
# speechbrain.utils.epoch_loop - Going into epoch 3
# 100% 79/79 [00:41<00:00,  1.88it/s, train_loss=0.0218]
# 100% 32/32 [00:17<00:00,  1.88it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0018 to 0.0017
# speechbrain.utils.train_logger - Epoch: 3, lr: 1.81e-03 - train loss: 2.18e-02 - valid loss: 2.22e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-23-23+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-22-24+00
# speechbrain.utils.epoch_loop - Going into epoch 4
# 100% 79/79 [00:42<00:00,  1.85it/s, train_loss=0.021]
# 100% 32/32 [00:17<00:00,  1.85it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0017 to 0.0016
# speechbrain.utils.train_logger - Epoch: 4, lr: 1.72e-03 - train loss: 2.10e-02 - valid loss: 2.15e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-24-23+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-23-23+00
# speechbrain.utils.epoch_loop - Going into epoch 5
# 100% 79/79 [00:42<00:00,  1.87it/s, train_loss=0.0206]
# 100% 32/32 [00:17<00:00,  1.86it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0016 to 0.0015
# speechbrain.utils.train_logger - Epoch: 5, lr: 1.62e-03 - train loss: 2.06e-02 - valid loss: 2.12e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-25-23+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-24-23+00
# speechbrain.utils.epoch_loop - Going into epoch 6
# 100% 79/79 [00:42<00:00,  1.87it/s, train_loss=0.0204]
# 100% 32/32 [00:17<00:00,  1.87it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0015 to 0.0014
# speechbrain.utils.train_logger - Epoch: 6, lr: 1.53e-03 - train loss: 2.04e-02 - valid loss: 2.09e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-26-22+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-25-23+00
# speechbrain.utils.epoch_loop - Going into epoch 7
# 100% 79/79 [00:42<00:00,  1.86it/s, train_loss=0.0202]
# 100% 32/32 [00:17<00:00,  1.81it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0014 to 0.0013
# speechbrain.utils.train_logger - Epoch: 7, lr: 1.43e-03 - train loss: 2.02e-02 - valid loss: 2.08e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-27-22+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-26-22+00
# speechbrain.utils.epoch_loop - Going into epoch 8
# 100% 79/79 [00:42<00:00,  1.84it/s, train_loss=0.0201]
# 100% 32/32 [00:17<00:00,  1.85it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0013 to 0.0012
# speechbrain.utils.train_logger - Epoch: 8, lr: 1.34e-03 - train loss: 2.01e-02 - valid loss: 2.08e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-28-22+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-27-22+00
# speechbrain.utils.epoch_loop - Going into epoch 9
# 100% 79/79 [00:42<00:00,  1.87it/s, train_loss=0.0199]
# 100% 32/32 [00:17<00:00,  1.88it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0012 to 0.0011
# speechbrain.utils.train_logger - Epoch: 9, lr: 1.24e-03 - train loss: 1.99e-02 - valid loss: 2.06e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-29-22+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-28-22+00
# speechbrain.utils.epoch_loop - Going into epoch 10
# 100% 79/79 [00:41<00:00,  1.90it/s, train_loss=0.0197]
# 100% 32/32 [00:17<00:00,  1.81it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0011 to 0.0011
# speechbrain.utils.train_logger - Epoch: 10, lr: 1.15e-03 - train loss: 1.97e-02 - valid loss: 2.06e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-30-21+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-29-22+00
# speechbrain.utils.epoch_loop - Going into epoch 11
# 100% 79/79 [00:42<00:00,  1.84it/s, train_loss=0.0196]
# 100% 32/32 [00:17<00:00,  1.80it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0011 to 0.00096
# speechbrain.utils.train_logger - Epoch: 11, lr: 1.05e-03 - train loss: 1.96e-02 - valid loss: 2.05e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-31-22+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-30-21+00
# speechbrain.utils.epoch_loop - Going into epoch 12
# 100% 79/79 [00:41<00:00,  1.90it/s, train_loss=0.0195]
# 100% 32/32 [00:17<00:00,  1.78it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00096 to 0.00086
# speechbrain.utils.train_logger - Epoch: 12, lr: 9.58e-04 - train loss: 1.95e-02 - valid loss: 2.04e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-32-21+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-31-22+00
# speechbrain.utils.epoch_loop - Going into epoch 13
# 100% 79/79 [00:41<00:00,  1.90it/s, train_loss=0.0194]
# 100% 32/32 [00:17<00:00,  1.79it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00086 to 0.00077
# speechbrain.utils.train_logger - Epoch: 13, lr: 8.63e-04 - train loss: 1.94e-02 - valid loss: 2.04e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-33-21+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-32-21+00
# speechbrain.utils.epoch_loop - Going into epoch 14
# 100% 79/79 [00:41<00:00,  1.90it/s, train_loss=0.0193]
# 100% 32/32 [00:17<00:00,  1.79it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00077 to 0.00067
# speechbrain.utils.train_logger - Epoch: 14, lr: 7.68e-04 - train loss: 1.93e-02 - valid loss: 2.03e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-34-20+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-33-21+00
# speechbrain.utils.epoch_loop - Going into epoch 15
# 100% 79/79 [00:41<00:00,  1.91it/s, train_loss=0.0193]
# 100% 32/32 [00:17<00:00,  1.79it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00067 to 0.00058
# speechbrain.utils.train_logger - Epoch: 15, lr: 6.74e-04 - train loss: 1.93e-02 - valid loss: 2.03e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-35-20+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-34-20+00
# speechbrain.utils.epoch_loop - Going into epoch 16
# 100% 79/79 [00:41<00:00,  1.91it/s, train_loss=0.0192]
# 100% 32/32 [00:17<00:00,  1.80it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00058 to 0.00048
# speechbrain.utils.train_logger - Epoch: 16, lr: 5.79e-04 - train loss: 1.92e-02 - valid loss: 2.02e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-36-19+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-35-20+00
# speechbrain.utils.epoch_loop - Going into epoch 17
# 100% 79/79 [00:41<00:00,  1.92it/s, train_loss=0.0192]
# 100% 32/32 [00:17<00:00,  1.86it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00048 to 0.00039
# speechbrain.utils.train_logger - Epoch: 17, lr: 4.84e-04 - train loss: 1.92e-02 - valid loss: 2.02e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-37-17+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-36-19+00
# speechbrain.utils.epoch_loop - Going into epoch 18
# 100% 79/79 [00:42<00:00,  1.86it/s, train_loss=0.0191]
# 100% 32/32 [00:17<00:00,  1.88it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00039 to 0.00029
# speechbrain.utils.train_logger - Epoch: 18, lr: 3.89e-04 - train loss: 1.91e-02 - valid loss: 2.02e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-38-17+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-37-17+00
# speechbrain.utils.epoch_loop - Going into epoch 19
# 100% 79/79 [00:42<00:00,  1.87it/s, train_loss=0.0191]
# 100% 32/32 [00:17<00:00,  1.86it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00029 to 0.0002
# speechbrain.utils.train_logger - Epoch: 19, lr: 2.95e-04 - train loss: 1.91e-02 - valid loss: 2.01e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-39-16+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-38-17+00
# speechbrain.utils.epoch_loop - Going into epoch 20
# 100% 79/79 [00:42<00:00,  1.87it/s, train_loss=0.0191]
# 100% 32/32 [00:17<00:00,  1.86it/s]
# speechbrain.utils.train_logger - Epoch: 20, lr: 2.00e-04 - train loss: 1.91e-02 - valid loss: 2.01e-02
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-40-16+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Autoencoder/1986/save/CKPT+2024-02-04+18-39-16+00
# speechbrain.utils.checkpoints - Would load a checkpoint here, but none found yet.
# 100% 32/32 [00:20<00:00,  1.53it/s]
# speechbrain.utils.train_logger - Epoch loaded: 20 - test loss: 2.02e-02

# %% [markdown]
# You should see the following training logs:
#
#
#
# ```
# Epoch: 1, lr: 2.00e-03 - train loss: 2.86e-02 - valid loss: 2.48e-02
# Epoch: 2, lr: 1.91e-03 - train loss: 2.27e-02 - valid loss: 2.36e-02
# Epoch: 3, lr: 1.81e-03 - train loss: 2.17e-02 - valid loss: 2.27e-02
# Epoch: 4, lr: 1.72e-03 - train loss: 2.10e-02 - valid loss: 2.22e-02
# Epoch: 5, lr: 1.62e-03 - train loss: 2.06e-02 - valid loss: 2.20e-02
# Epoch: 6, lr: 1.53e-03 - train loss: 2.04e-02 - valid loss: 2.17e-02
# Epoch: 7, lr: 1.43e-03 - train loss: 2.02e-02 - valid loss: 2.14e-02
# Epoch: 8, lr: 1.34e-03 - train loss: 2.00e-02 - valid loss: 2.14e-02
# Epoch: 9, lr: 1.24e-03 - train loss: 1.99e-02 - valid loss: 2.12e-02
# Epoch: 10, lr: 1.15e-03 - train loss: 1.97e-02 - valid loss: 2.11e-02
# Epoch: 11, lr: 1.05e-03 - train loss: 1.96e-02 - valid loss: 2.11e-02
# Epoch: 12, lr: 9.58e-04 - train loss: 1.95e-02 - valid loss: 2.10e-02
# Epoch: 13, lr: 8.63e-04 - train loss: 1.94e-02 - valid loss: 2.08e-02
# Epoch: 14, lr: 7.68e-04 - train loss: 1.94e-02 - valid loss: 2.08e-02
# Epoch: 15, lr: 6.74e-04 - train loss: 1.93e-02 - valid loss: 2.07e-02
# Epoch: 16, lr: 5.79e-04 - train loss: 1.93e-02 - valid loss: 2.05e-02
# Epoch: 17, lr: 4.84e-04 - train loss: 1.92e-02 - valid loss: 2.04e-02
# Epoch: 18, lr: 3.89e-04 - train loss: 1.92e-02 - valid loss: 2.02e-02
# Epoch: 19, lr: 2.95e-04 - train loss: 1.92e-02 - valid loss: 2.01e-02
# Epoch: 20, lr: 2.00e-04 - train loss: 1.91e-02 - valid loss: 2.00e-02
# Epoch loaded: 20 - test loss: 2.00e-02
# ```
#
# Some variability is possible with different seeds.

# %% [markdown]
# **Run the code below** to plot and play one reconstructed signal.

# %%
import matplotlib.pyplot as plt
original_file = '/content/results/AudioMNIST/Autoencoder/1986/samples/1_17_40_original.wav'
reconstructed_file = '/content/results/AudioMNIST/Autoencoder/1986/samples/1_17_40.wav'

# Orignal Signal
sig, fs = torchaudio.load(original_file)
plt.title("Original Audio")
plt.plot(sig.squeeze())
plt.show()

# Reconstruction
rec, fs = torchaudio.load(reconstructed_file)
plt.title("Reconstructed Audio")
plt.plot(rec.squeeze())
plt.show()

Audio(rec, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# You can compare the reconstructed audio with the original one:

# %%
Audio(sig, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# From the plots, you should see that the waveforms are pretty different. If you play the reconstructed signal, you should hear a lot of distortion due to compression. However, the content of the signal should stay ineligible. For instance, you should hear a "1" in this signal.

# %% [markdown]
# **Run the code below** to store the best encoder:

# %%
# !cp results/AudioMNIST/Autoencoder/1986/save/CKPT*/encoder.ckpt encoder_best.ckpt

# %% [markdown]
# ##**Exercise 3 - Classification**
#
# Now, we will build a digit classifier on top of the learned features. This is very similar to what was done in the previous lab, but we replace the feature extraction and embedding block with the learned autoencoder:

# %% [markdown]
# ![pictures-Page-1.drawio (1).png](data:image/png;base64,...)

# %% [markdown]
# ### **Exercise 3.1 - Encoder Fine-Tuning**
#
# The encoder is a convolutional neural network. The main advantage over traditional feature extraction (e.g., FBANKs) is that we can backpropagate through it and fine-tune it during training. This approach is usually very effective as it adapts the learned features to the final task (called the downstream task).
#
# In this exercise, we train the MLP digit classifier on top of the encoded representations. The encoder is fine-tuned while training the classifier.
#
# **Run the code below** to store the hyperparameters of the digit classifier.

# %%
# %%file hparams_classifier_finetuned.yaml
#
# # #################################
# # Digit Classifier with a Pretrained autoencoder
# # #################################
#
# # Seed needs to be set at top of yaml, before objects with parameters are made
# seed: 1986
# __set_seed: !!python/object/apply:torch.manual_seed [!ref <seed>]
#
# output_folder: !ref ./results/AudioMNIST/Classifier-fine-tuned/<seed>
# save_folder: !ref <output_folder>/save
# train_log: !ref <output_folder>/train_log.txt
#
# # Path where data manifest files are stored
# train_annotation: train.json
# valid_annotation: valid.json
# test_annotation: test.json
#
# # The train logger writes training statistics to a file, as well as stdout.
# train_logger: !new:speechbrain.utils.train_logger.FileTrainLogger
#     save_file: !ref <train_log>
#
# error_stats: !name:speechbrain.utils.metric_stats.MetricStats
#     metric: !name:speechbrain.nnet.losses.classification_error
#         reduction: batch
#
#
# # Training Parameters
# number_of_epochs: 30
# batch_size: 64
# lr_start: 0.001
# lr_final: 0.0001
# n_classes: 10 # In this case, we have 10 digits
# emb_dim: 128 # dimensionality of the embeddings
# dataloader_options:
#     batch_size: !ref <batch_size>
#
# # Encoder
# n_fea: 40
# encoder: !new:models.Encoder
#
# # Clasifier applied on top of the embeddings
# classifier: !new:speechbrain.lobes.models.Xvector.Classifier
#     input_shape: [null, null, !ref <n_fea>]
#     activation: !name:torch.nn.LeakyReLU
#     lin_blocks: 1
#     lin_neurons: 128
#     out_neurons: !ref <n_classes>
#
# # The first object passed to the Brain class is this "Epoch Counter"
# # which is saved by the Checkpointer so that training can be resumed
# # if it gets interrupted at any point.
# epoch_counter: !new:speechbrain.utils.epoch_loop.EpochCounter
#     limit: !ref <number_of_epochs>
#
# # Objects in "modules" dict will have their parameters moved to the correct
# # device, as well as having train()/eval() called on them by the Brain class.
# modules:
#     encoder: !ref <encoder>
#     classifier: !ref <classifier>
#
# # This optimizer will be constructed by the Brain class after all parameters
# # are moved to the correct device. Then it will be added to the checkpointer.
# opt_class: !name:torch.optim.Adam
#     lr: !ref <lr_start>
#
# # This function manages learning rate annealing over the epochs.
# # We here use the simple lr annealing method that linearly decreases
# # the lr from the initial value to the final one.
# lr_annealing: !new:speechbrain.nnet.schedulers.LinearScheduler
#     initial_value: !ref <lr_start>
#     final_value: !ref <lr_final>
#     epoch_count: !ref <number_of_epochs>
#
# # This object is used for saving the state of training both so that it
# # can be resumed if it gets interrupted, and also so that the best checkpoint
# # can be later loaded for evaluation or inference.
# checkpointer: !new:speechbrain.utils.checkpoints.Checkpointer
#     checkpoints_dir: !ref <save_folder>
#     recoverables:
#         encoder: !ref <encoder>
#         classifier: !ref <classifier>
#         counter: !ref <epoch_counter>
#
# # This object is used to pretrain the elements listed in loadables with
# # the parameters stored in the corresponding paths.
# pretrainer: !new:speechbrain.utils.parameter_transfer.Pretrainer
#    collect_in: !ref <save_folder>
#    loadables:
#       encoder: !ref <encoder>
#    paths:
#       encoder: /content/encoder_best.ckpt
# Out:
# Writing hparams_classifier_finetuned.yaml

# %% [markdown]
# **Complete the code below** to train the digit classifier. You need to complete the forward and compute objective methods. You also need to resample the data on-the-fly to get 16 kHz data. You can draw inspiration from the previous lab (you need to remove the feature extraction and embedding computation and replace it with the encoder).

# %%
# %%file train.py

#!/usr/bin/env python3
"Recipe for training a digit classification system."
import os
import sys
import torch
import torchaudio
from speechbrain.utils.distributed import run_on_main
import speechbrain as sb
from hyperpyyaml import load_hyperpyyaml
from speechbrain.dataio.dataio import length_to_mask

# Brain class for speech enhancement training
class DigitBrain(sb.Brain):
    """Class that manages the training loop. See speechbrain.core.Brain."""

    def compute_forward(self, batch, stage):
        """Runs all the computations that transforms the input into the
        output probabilities over the N classes.

        Arguments
        ---------
        batch : PaddedBatch
            This batch object contains all the relevant tensors for computation.
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, or sb.Stage.TEST.
        Returns
        -------
        predictions : Tensor
            Tensor that contains the posterior probabilities over the N classes.
        """

        # We first move the batch to the appropriate device.
        batch = batch.to(self.device)

        # Unpacking batch
        wavs, lens = batch.sig

        # Compute encoded representations
        # Your code here. Aim for 1-2 line.
        # Make sure you feed the encoder with the expected tensor shape.
        # The encoded feature should have the format [batch,time, channels].
        enc_fea = self.modules.encoder(wavs.unsqueeze(1))
        enc_fea = enc_fea.transpose(1,2)

        # Average the encoder representation over time (to get a single
        # vector for the classifier)
        abs_len = (lens * enc_fea.shape[1]).int()
        mask = length_to_mask(abs_len)
        masked_x = enc_fea * mask.unsqueeze(2)
        embeddings = masked_x.sum(dim=1)/mask.sum(dim=1, keepdim=True)
        embeddings = embeddings.unsqueeze(1)

        # Final classification
        predictions = self.modules.classifier(embeddings)

        return predictions


    def compute_objectives(self, predictions, batch, stage):
        """Computes the loss given the predicted and targeted outputs.

        Arguments
        ---------
        predictions : tensor
            The output tensor from `compute_forward`.
        batch : PaddedBatch
            This batch object contains all the relevant tensors for computation.
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, or sb.Stage.TEST.
        Returns
        -------
        loss : torch.Tensor
            A one-element tensor used for backpropagating the gradient.
        """

        _, lens = batch.sig
        labels, _ = batch.digit_encoded

        # Compute the cost function.
        # Your code here. Aim for 1 line
        loss = sb.nnet.losses.nll_loss(predictions, labels, lens)

        # Append this batch of losses to the loss metric for easy
        self.loss_metric.append(
            batch.id, predictions, labels, lens, reduction="batch"
        )

        # Compute classification error at test time
        if stage != sb.Stage.TRAIN:
            self.error_metrics.append(batch.id, predictions, labels, lens)

        return loss

    def on_stage_start(self, stage, epoch=None):
        """Gets called at the beginning of each epoch.
        Arguments
        ---------
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, or sb.Stage.TEST.
        epoch : int
            The currently-starting epoch. This is passed
            `None` during the test stage.
        """

        # Set up statistics trackers for this stage
        self.loss_metric = sb.utils.metric_stats.MetricStats(
            metric=sb.nnet.losses.nll_loss
        )

        # Set up evaluation-only statistics trackers
        if stage != sb.Stage.TRAIN:
            self.error_metrics = self.hparams.error_stats()

    def on_stage_end(self, stage, stage_loss, epoch=None):
        """Gets called at the end of an epoch.
        Arguments
        ---------
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, sb.Stage.TEST
        stage_loss : float
            The average loss for all of the data processed in this stage.
        epoch : int
            The currently-starting epoch. This is passed
            `None` during the test stage.
        """

        # Store the train loss until the validation stage.
        if stage == sb.Stage.TRAIN:
            self.train_loss = stage_loss

        # Summarize the statistics from the stage for record-keeping.
        else:
            stats = {
                "loss": stage_loss,
                "error": self.error_metrics.summarize("average"),
            }

        # At the end of validation...
        if stage == sb.Stage.VALID:

            old_lr, new_lr = self.hparams.lr_annealing(epoch)
            sb.nnet.schedulers.update_learning_rate(self.optimizer, new_lr)

            # The train_logger writes a summary to stdout and to the logfile.
            self.hparams.train_logger.log_stats(
                {"Epoch": epoch, "lr": old_lr},
                train_stats={"loss": self.train_loss},
                valid_stats=stats,
            )

            # Save the current checkpoint and delete previous checkpoints,
            self.checkpointer.save_and_keep_only(meta=stats, min_keys=["error"])

        # We also write statistics about test data to stdout and to the logfile.
        if stage == sb.Stage.TEST:
            self.hparams.train_logger.log_stats(
                {"Epoch loaded": self.hparams.epoch_counter.current},
                test_stats=stats,
            )


def dataio_prep(hparams):
    """This function prepares the datasets to be used in the brain class.
    It also defines the data processing pipeline through user-defined functions.
    We expect `prepare_mini_librispeech` to have been called before this,
    so that the `train.json`, `valid.json`,  and `valid.json` manifest files
    are available.
    Arguments
    ---------
    hparams : dict
        This dictionary is loaded from the `train.yaml` file, and it includes
        all the hyperparameters needed for dataset construction and loading.
    Returns
    -------
    datasets : dict
        Contains two keys, "train" and "valid" that correspond
        to the appropriate DynamicItemDataset object.
    """

    # Initialization of the label encoder. The label encoder assigns to each
    # of the observed label a unique index (e.g, 'digit0': 0, 'digit1': 1, ..)
    label_encoder = sb.dataio.encoder.CategoricalEncoder()

    # Define audio pipeline
    @sb.utils.data_pipeline.takes("wav")
    @sb.utils.data_pipeline.provides("sig")
    def audio_pipeline(wav):
        """Load the signal, and pass it and its length to the corruption class.
        This is done on the CPU in the `collate_fn`."""
        sig, fs = torchaudio.load(wav)

        # Resampling
        # Your code here. Aim for 1-2 lines
        sig = torchaudio.functional.resample(sig, fs, 16000).squeeze(0)
        return sig

    # Define label pipeline:
    @sb.utils.data_pipeline.takes("digit")
    @sb.utils.data_pipeline.provides("digit", "digit_encoded")
    def label_pipeline(digit):
        """Defines the pipeline to process the digit labels.
        Note that we have to assign a different integer to each class
        through the label encoder.
        """
        yield digit
        digit_encoded = label_encoder.encode_label_torch(digit)
        yield digit_encoded

    # Define datasets. We also connect the dataset with the data processing
    # functions defined above.
    datasets = {}
    data_info = {
        "train": hparams["train_annotation"],
        "valid": hparams["valid_annotation"],
        "test": hparams["test_annotation"],
    }
    hparams["dataloader_options"]["shuffle"] = True
    for dataset in data_info:
        datasets[dataset] = sb.dataio.dataset.DynamicItemDataset.from_json(
            json_path=data_info[dataset],
            dynamic_items=[audio_pipeline, label_pipeline],
            output_keys=["id", "sig", "digit_encoded"],
        )

    # Load or compute the label encoder (with multi-GPU DDP support)
    # Please, take a look into the lab_enc_file to see the label to index
    # mapping.
    lab_enc_file = os.path.join(hparams["save_folder"], "label_encoder.txt")
    label_encoder.load_or_create(
        path=lab_enc_file,
        from_didatasets=[datasets["train"]],
        output_key="digit",
    )

    return datasets


# Recipe begins!
if __name__ == "__main__":

    # Reading command line arguments.
    hparams_file, run_opts, overrides = sb.parse_arguments(sys.argv[1:])

    # Load hyperparameters file with command-line overrides.
    with open(hparams_file) as fin:
        hparams = load_hyperpyyaml(fin,  overrides)

    # Create experiment directory
    sb.create_experiment_directory(
        experiment_directory=hparams["output_folder"],
        hyperparams_to_save=hparams_file,
        overrides=overrides,
    )

    # Create dataset objects "train", "valid", and "test".
    datasets = dataio_prep(hparams)

    # Download and Pretrain the encoder
    hparams["pretrainer"].collect_files()
    hparams["pretrainer"].load_collected()
    hparams["encoder"].to(run_opts["device"])

    # Initialize the Brain object to prepare for mask training.
    digit_brain = DigitBrain(
        modules=hparams["modules"],
        opt_class=hparams["opt_class"],
        hparams=hparams,
        run_opts=run_opts,
        checkpointer=hparams["checkpointer"],
    )

    # The `fit()` method iterates the training loop, calling the methods
    # necessary to update the parameters of the model. Since all objects
    # with changing state are managed by the Checkpointer, training can be
    # stopped at any point, and will be resumed on next call.
    digit_brain.fit(
        epoch_counter=digit_brain.hparams.epoch_counter,
        train_set=datasets["train"],
        valid_set=datasets["valid"],
        train_loader_kwargs=hparams["dataloader_options"],
        valid_loader_kwargs=hparams["dataloader_options"],
    )

    # Load the best checkpoint for evaluation
    test_stats = digit_brain.evaluate(
        test_set=datasets["test"],
        min_key="error",
        test_loader_kwargs=hparams["dataloader_options"],
    )
# Out:
# Overwriting train.py

# %% [markdown]
# **Run the code below** to start training.

# %%
# To start from scratch, you need to remove the output folder.
# Otherwise, speechbrain starts from the last valid checkpoint.
#!rm -rf ./results/AudioMNIST/Classifier-fine-tuned/

# !python train.py hparams_classifier_finetuned.yaml
# Out:
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: ./results/AudioMNIST/Classifier-fine-tuned/1986
# speechbrain.dataio.encoder - Load called, but CategoricalEncoder is not empty. Loaded data will overwrite everything. This is normal if there is e.g. an unk label defined at init.
# speechbrain.pretrained.fetching - Destination encoder_best.ckpt: local file in /content/encoder_best.ckpt.
# speechbrain.utils.parameter_transfer - Set local path in self.paths[encoder] = results/AudioMNIST/Classifier-fine-tuned/1986/save/encoder.ckpt
# speechbrain.utils.parameter_transfer - Loading pretrained files for: encoder
# speechbrain.utils.parameter_transfer - Redirecting (loading from local path): results/AudioMNIST/Classifier-fine-tuned/1986/save/encoder.ckpt -> results/AudioMNIST/Classifier-fine-tuned/1986/save/encoder.ckpt
# speechbrain.core - 8.5k trainable parameters in DigitBrain
# speechbrain.utils.checkpoints - Would load a checkpoint here, but none found yet.
# speechbrain.utils.epoch_loop - Going into epoch 1
#   0% 0/79 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/speechbrain/dataio/encoder.py:722: UserWarning: CategoricalEncoder.expect_len was never called: assuming category count of 10 to be correct! Sanity check your encoder using `.expect_len`. Ensure that downstream code also uses the correct size. If you are sure this does not apply to you, use `.ignore_len`.
#   warnings.warn(
# 100% 79/79 [00:41<00:00,  1.90it/s, train_loss=2.25]
# 100% 32/32 [00:17<00:00,  1.80it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.001 to 0.00097
# speechbrain.utils.train_logger - Epoch: 1, lr: 1.00e-03 - train loss: 2.25 - valid loss: 2.34, valid error: 8.90e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-41-44+00
# speechbrain.utils.epoch_loop - Going into epoch 2
# 100% 79/79 [00:42<00:00,  1.86it/s, train_loss=2.04]
# 100% 32/32 [00:17<00:00,  1.84it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00097 to 0.00094
# speechbrain.utils.train_logger - Epoch: 2, lr: 9.69e-04 - train loss: 2.04 - valid loss: 2.24, valid error: 7.93e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-42-44+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-41-44+00
# speechbrain.utils.epoch_loop - Going into epoch 3
# 100% 79/79 [00:42<00:00,  1.86it/s, train_loss=1.91]
# 100% 32/32 [00:17<00:00,  1.84it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00094 to 0.00091
# speechbrain.utils.train_logger - Epoch: 3, lr: 9.38e-04 - train loss: 1.91 - valid loss: 1.94, valid error: 7.47e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-43-44+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-42-44+00
# speechbrain.utils.epoch_loop - Going into epoch 4
# 100% 79/79 [00:42<00:00,  1.87it/s, train_loss=1.76]
# 100% 32/32 [00:17<00:00,  1.82it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00091 to 0.00088
# speechbrain.utils.train_logger - Epoch: 4, lr: 9.07e-04 - train loss: 1.76 - valid loss: 2.47, valid error: 8.57e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-44-44+00
# speechbrain.utils.epoch_loop - Going into epoch 5
# 100% 79/79 [00:42<00:00,  1.88it/s, train_loss=1.56]
# 100% 32/32 [00:17<00:00,  1.88it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00088 to 0.00084
# speechbrain.utils.train_logger - Epoch: 5, lr: 8.76e-04 - train loss: 1.56 - valid loss: 5.38, valid error: 8.89e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-45-43+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-44-44+00
# speechbrain.utils.epoch_loop - Going into epoch 6
# 100% 79/79 [00:42<00:00,  1.88it/s, train_loss=1.48]
# 100% 32/32 [00:17<00:00,  1.88it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00084 to 0.00081
# speechbrain.utils.train_logger - Epoch: 6, lr: 8.45e-04 - train loss: 1.48 - valid loss: 2.49, valid error: 7.66e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-46-43+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-45-43+00
# speechbrain.utils.epoch_loop - Going into epoch 7
# 100% 79/79 [00:42<00:00,  1.87it/s, train_loss=1.3]
# 100% 32/32 [00:17<00:00,  1.88it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00081 to 0.00078
# speechbrain.utils.train_logger - Epoch: 7, lr: 8.14e-04 - train loss: 1.30 - valid loss: 4.30, valid error: 7.81e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-47-42+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-46-43+00
# speechbrain.utils.epoch_loop - Going into epoch 8
# 100% 79/79 [00:42<00:00,  1.88it/s, train_loss=1.23]
# 100% 32/32 [00:17<00:00,  1.88it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00078 to 0.00075
# speechbrain.utils.train_logger - Epoch: 8, lr: 7.83e-04 - train loss: 1.23 - valid loss: 1.66, valid error: 5.85e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-48-41+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-43-44+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-47-42+00
# speechbrain.utils.epoch_loop - Going into epoch 9
# 100% 79/79 [00:42<00:00,  1.88it/s, train_loss=1.18]
# 100% 32/32 [00:17<00:00,  1.85it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00075 to 0.00072
# speechbrain.utils.train_logger - Epoch: 9, lr: 7.52e-04 - train loss: 1.18 - valid loss: 2.16, valid error: 6.68e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-49-41+00
# speechbrain.utils.epoch_loop - Going into epoch 10
# 100% 79/79 [00:42<00:00,  1.88it/s, train_loss=1.16]
# 100% 32/32 [00:17<00:00,  1.80it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00072 to 0.00069
# speechbrain.utils.train_logger - Epoch: 10, lr: 7.21e-04 - train loss: 1.16 - valid loss: 5.45, valid error: 8.14e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-50-41+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-49-41+00
# speechbrain.utils.epoch_loop - Going into epoch 11
# 100% 79/79 [00:42<00:00,  1.87it/s, train_loss=1.12]
# 100% 32/32 [00:17<00:00,  1.79it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00069 to 0.00066
# speechbrain.utils.train_logger - Epoch: 11, lr: 6.90e-04 - train loss: 1.12 - valid loss: 3.47, valid error: 7.89e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-51-41+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-50-41+00
# speechbrain.utils.epoch_loop - Going into epoch 12
# 100% 79/79 [00:42<00:00,  1.87it/s, train_loss=1.13]
# 100% 32/32 [00:18<00:00,  1.77it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00066 to 0.00063
# speechbrain.utils.train_logger - Epoch: 12, lr: 6.59e-04 - train loss: 1.13 - valid loss: 2.18, valid error: 7.04e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-52-42+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-51-41+00
# speechbrain.utils.epoch_loop - Going into epoch 13
# 100% 79/79 [00:42<00:00,  1.86it/s, train_loss=1.08]
# 100% 32/32 [00:18<00:00,  1.69it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00063 to 0.0006
# speechbrain.utils.train_logger - Epoch: 13, lr: 6.28e-04 - train loss: 1.08 - valid loss: 1.74, valid error: 5.79e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-53-43+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-48-41+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-52-42+00
# speechbrain.utils.epoch_loop - Going into epoch 14
# 100% 79/79 [00:43<00:00,  1.82it/s, train_loss=1.09]
# 100% 32/32 [00:17<00:00,  1.82it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0006 to 0.00057
# speechbrain.utils.train_logger - Epoch: 14, lr: 5.97e-04 - train loss: 1.09 - valid loss: 1.94, valid error: 6.06e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-54-44+00
# speechbrain.utils.epoch_loop - Going into epoch 15
# 100% 79/79 [00:43<00:00,  1.81it/s, train_loss=1.05]
# 100% 32/32 [00:17<00:00,  1.80it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00057 to 0.00053
# speechbrain.utils.train_logger - Epoch: 15, lr: 5.66e-04 - train loss: 1.05 - valid loss: 1.33, valid error: 5.47e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-55-46+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-54-44+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-53-43+00
# speechbrain.utils.epoch_loop - Going into epoch 16
# 100% 79/79 [00:43<00:00,  1.80it/s, train_loss=1.04]
# 100% 32/32 [00:17<00:00,  1.81it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00053 to 0.0005
# speechbrain.utils.train_logger - Epoch: 16, lr: 5.34e-04 - train loss: 1.04 - valid loss: 1.39, valid error: 5.46e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-56-48+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-55-46+00
# speechbrain.utils.epoch_loop - Going into epoch 17
# 100% 79/79 [00:43<00:00,  1.81it/s, train_loss=1.05]
# 100% 32/32 [00:17<00:00,  1.82it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0005 to 0.00047
# speechbrain.utils.train_logger - Epoch: 17, lr: 5.03e-04 - train loss: 1.05 - valid loss: 1.90, valid error: 5.76e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-57-49+00
# speechbrain.utils.epoch_loop - Going into epoch 18
# 100% 79/79 [00:43<00:00,  1.80it/s, train_loss=1.03]
# 100% 32/32 [00:17<00:00,  1.81it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00047 to 0.00044
# speechbrain.utils.train_logger - Epoch: 18, lr: 4.72e-04 - train loss: 1.03 - valid loss: 1.44, valid error: 5.47e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-58-50+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-57-49+00
# speechbrain.utils.epoch_loop - Going into epoch 19
# 100% 79/79 [00:43<00:00,  1.81it/s, train_loss=1.03]
# 100% 32/32 [00:17<00:00,  1.82it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00044 to 0.00041
# speechbrain.utils.train_logger - Epoch: 19, lr: 4.41e-04 - train loss: 1.03 - valid loss: 1.07, valid error: 4.32e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-59-52+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-58-50+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-56-48+00
# speechbrain.utils.epoch_loop - Going into epoch 20
# 100% 79/79 [00:44<00:00,  1.79it/s, train_loss=1]
# 100% 32/32 [00:18<00:00,  1.74it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00041 to 0.00038
# speechbrain.utils.train_logger - Epoch: 20, lr: 4.10e-04 - train loss: 1.00 - valid loss: 1.43, valid error: 5.27e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-00-54+00
# speechbrain.utils.epoch_loop - Going into epoch 21
# 100% 79/79 [00:42<00:00,  1.84it/s, train_loss=1.01]
# 100% 32/32 [00:18<00:00,  1.74it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00038 to 0.00035
# speechbrain.utils.train_logger - Epoch: 21, lr: 3.79e-04 - train loss: 1.01 - valid loss: 2.37, valid error: 6.42e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-01-56+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-00-54+00
# speechbrain.utils.epoch_loop - Going into epoch 22
# 100% 79/79 [00:42<00:00,  1.86it/s, train_loss=1.01]
# 100% 32/32 [00:18<00:00,  1.74it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00035 to 0.00032
# speechbrain.utils.train_logger - Epoch: 22, lr: 3.48e-04 - train loss: 1.01 - valid loss: 3.05, valid error: 7.97e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-02-57+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-01-56+00
# speechbrain.utils.epoch_loop - Going into epoch 23
# 100% 79/79 [00:42<00:00,  1.86it/s, train_loss=0.988]
# 100% 32/32 [00:18<00:00,  1.75it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00032 to 0.00029
# speechbrain.utils.train_logger - Epoch: 23, lr: 3.17e-04 - train loss: 9.88e-01 - valid loss: 2.00, valid error: 5.90e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-03-58+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-02-57+00
# speechbrain.utils.epoch_loop - Going into epoch 24
# 100% 79/79 [00:43<00:00,  1.83it/s, train_loss=0.976]
# 100% 32/32 [00:20<00:00,  1.58it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00029 to 0.00026
# speechbrain.utils.train_logger - Epoch: 24, lr: 2.86e-04 - train loss: 9.76e-01 - valid loss: 1.37, valid error: 5.23e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-05-01+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-03-58+00
# speechbrain.utils.epoch_loop - Going into epoch 25
# 100% 79/79 [00:42<00:00,  1.84it/s, train_loss=1]
# 100% 32/32 [00:18<00:00,  1.72it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00026 to 0.00022
# speechbrain.utils.train_logger - Epoch: 25, lr: 2.55e-04 - train loss: 1.00 - valid loss: 3.35, valid error: 8.19e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-06-03+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-05-01+00
# speechbrain.utils.epoch_loop - Going into epoch 26
# 100% 79/79 [00:43<00:00,  1.84it/s, train_loss=0.966]
# 100% 32/32 [00:18<00:00,  1.77it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00022 to 0.00019
# speechbrain.utils.train_logger - Epoch: 26, lr: 2.24e-04 - train loss: 9.66e-01 - valid loss: 1.42, valid error: 5.16e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-07-04+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-06-03+00
# speechbrain.utils.epoch_loop - Going into epoch 27
# 100% 79/79 [00:43<00:00,  1.80it/s, train_loss=0.949]
# 100% 32/32 [00:17<00:00,  1.78it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00019 to 0.00016
# speechbrain.utils.train_logger - Epoch: 27, lr: 1.93e-04 - train loss: 9.49e-01 - valid loss: 1.09, valid error: 4.31e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-08-06+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+18-59-52+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-07-04+00
# speechbrain.utils.epoch_loop - Going into epoch 28
# 100% 79/79 [00:43<00:00,  1.80it/s, train_loss=0.974]
# 100% 32/32 [00:17<00:00,  1.80it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00016 to 0.00013
# speechbrain.utils.train_logger - Epoch: 28, lr: 1.62e-04 - train loss: 9.74e-01 - valid loss: 2.25, valid error: 5.86e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-09-08+00
# speechbrain.utils.epoch_loop - Going into epoch 29
# 100% 79/79 [00:43<00:00,  1.82it/s, train_loss=0.941]
# 100% 32/32 [00:17<00:00,  1.78it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00013 to 0.0001
# speechbrain.utils.train_logger - Epoch: 29, lr: 1.31e-04 - train loss: 9.41e-01 - valid loss: 1.43, valid error: 5.67e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-10-10+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-09-08+00
# speechbrain.utils.epoch_loop - Going into epoch 30
# 100% 79/79 [00:43<00:00,  1.81it/s, train_loss=0.947]
# 100% 32/32 [00:17<00:00,  1.79it/s]
# speechbrain.utils.train_logger - Epoch: 30, lr: 1.00e-04 - train loss: 9.47e-01 - valid loss: 1.04, valid error: 4.11e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-11-12+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-10-10+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-08-06+00
# speechbrain.utils.checkpoints - Loading a checkpoint from results/AudioMNIST/Classifier-fine-tuned/1986/save/CKPT+2024-02-04+19-11-12+00
# 100% 32/32 [00:18<00:00,  1.74it/s]
# speechbrain.utils.train_logger - Epoch loaded: 30 - test loss: 1.23, test error: 4.47e-01

# %% [markdown]
# You should obtain training logs similar to these:
#
#
#
# ```
# Epoch: 1, lr: 1.00e-03 - train loss: 2.29 - valid loss: 2.22, valid error: 8.40e-01
# Epoch: 2, lr: 9.69e-04 - train loss: 2.02 - valid loss: 2.03, valid error: 7.55e-01
# Epoch: 3, lr: 9.38e-04 - train loss: 1.83 - valid loss: 1.92, valid error: 7.37e-01
# Epoch: 4, lr: 9.07e-04 - train loss: 1.65 - valid loss: 1.64, valid error: 7.03e-01
# Epoch: 5, lr: 8.76e-04 - train loss: 1.57 - valid loss: 2.48, valid error: 7.47e-01
# Epoch: 6, lr: 8.45e-04 - train loss: 1.49 - valid loss: 5.86, valid error: 8.98e-01
# Epoch: 7, lr: 8.14e-04 - train loss: 1.45 - valid loss: 1.37, valid error: 5.26e-01
# Epoch: 8, lr: 7.83e-04 - train loss: 1.40 - valid loss: 4.47, valid error: 8.61e-01
# Epoch: 9, lr: 7.52e-04 - train loss: 1.37 - valid loss: 2.26, valid error: 7.94e-01
# Epoch: 10, lr: 7.21e-04 - train loss: 1.31 - valid loss: 1.48, valid error: 5.66e-01
# Epoch: 11, lr: 6.90e-04 - train loss: 1.31 - valid loss: 2.88, valid error: 7.90e-01
# Epoch: 12, lr: 6.59e-04 - train loss: 1.28 - valid loss: 2.72, valid error: 8.23e-01
# Epoch: 13, lr: 6.28e-04 - train loss: 1.24 - valid loss: 1.79, valid error: 6.43e-01
# Epoch: 14, lr: 5.97e-04 - train loss: 1.25 - valid loss: 2.16, valid error: 6.76e-01
# Epoch: 15, lr: 5.66e-04 - train loss: 1.22 - valid loss: 1.45, valid error: 5.75e-01
# Epoch: 16, lr: 5.34e-04 - train loss: 1.23 - valid loss: 2.10, valid error: 7.20e-01
# Epoch: 17, lr: 5.03e-04 - train loss: 1.21 - valid loss: 2.87, valid error: 7.16e-01
# Epoch: 18, lr: 4.72e-04 - train loss: 1.20 - valid loss: 1.40, valid error: 5.13e-01
# Epoch: 19, lr: 4.41e-04 - train loss: 1.17 - valid loss: 1.88, valid error: 7.05e-01
# Epoch: 20, lr: 4.10e-04 - train loss: 1.18 - valid loss: 1.53, valid error: 6.22e-01
# Epoch: 21, lr: 3.79e-04 - train loss: 1.18 - valid loss: 2.42, valid error: 7.35e-01
# Epoch: 22, lr: 3.48e-04 - train loss: 1.14 - valid loss: 3.11, valid error: 8.40e-01
# Epoch: 23, lr: 3.17e-04 - train loss: 1.14 - valid loss: 2.04, valid error: 7.49e-01
# Epoch: 24, lr: 2.86e-04 - train loss: 1.12 - valid loss: 1.24, valid error: 4.56e-01
# Epoch: 25, lr: 2.55e-04 - train loss: 1.14 - valid loss: 1.22, valid error: 4.95e-01
# Epoch: 26, lr: 2.24e-04 - train loss: 1.13 - valid loss: 2.06, valid error: 7.52e-01
# Epoch: 27, lr: 1.93e-04 - train loss: 1.11 - valid loss: 1.44, valid error: 5.04e-01
# Epoch: 28, lr: 1.62e-04 - train loss: 1.12 - valid loss: 2.27, valid error: 6.45e-01
# Epoch: 29, lr: 1.31e-04 - train loss: 1.09 - valid loss: 1.34, valid error: 4.74e-01
# Epoch: 30, lr: 1.00e-04 - train loss: 1.09 - valid loss: 1.12, valid error: 4.29e-01
# Epoch loaded: 30 - test loss: 1.58, test error: 5.49e-01
# ```

# %% [markdown]
# ### **Exercise 3.2 - Frozen Encoder**
# Another alternative is to not fine-tune the encoder but keep it frozen during training.
#
# **Write the train.py** to train the model with the frozen encoder. You can copy and paste the code from the previous exercise and do the needed modification.
# Essentially, you need to put the model in eval modality and avoid computing the gradient (using `torch.no_grad()`). This can be done in the forward method.

# %%
# %%file train.py

#!/usr/bin/env python3
"Recipe for training a digit classification system."
import os
import sys
import torch
import torchaudio
from speechbrain.utils.distributed import run_on_main
import speechbrain as sb
from hyperpyyaml import load_hyperpyyaml
from speechbrain.dataio.dataio import length_to_mask

# Brain class for speech enhancement training
class DigitBrain(sb.Brain):
    """Class that manages the training loop. See speechbrain.core.Brain."""

    def compute_forward(self, batch, stage):
        """Runs all the computations that transforms the input into the
        output probabilities over the N classes.

        Arguments
        ---------
        batch : PaddedBatch
            This batch object contains all the relevant tensors for computation.
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, or sb.Stage.TEST.
        Returns
        -------
        predictions : Tensor
            Tensor that contains the posterior probabilities over the N classes.
        """

        # We first move the batch to the appropriate device.
        batch = batch.to(self.device)

        # Unpacking batch
        wavs, lens = batch.sig

        # Compute encoded representations
        # Your code here. Aim for 1-2 line.
        # Make sure you feed the encoder with the expected tensor shape.
        # The encoded feature should have the format [batch,time, channels].
        with torch.no_grad():
          enc_fea = self.modules.encoder(wavs.unsqueeze(1))
          enc_fea = enc_fea.transpose(1, 2)
        # Average the encoder representation over time (to get a single
        # vector for the classifier)
        abs_len = (lens * enc_fea.shape[1]).int()
        mask = length_to_mask(abs_len)
        masked_x = enc_fea * mask.unsqueeze(2)
        embeddings = masked_x.sum(dim=1)/mask.sum(dim=1, keepdim=True)
        embeddings = embeddings.unsqueeze(1)

        # Final classification
        predictions = self.modules.classifier(embeddings)

        return predictions


    def compute_objectives(self, predictions, batch, stage):
        """Computes the loss given the predicted and targeted outputs.

        Arguments
        ---------
        predictions : tensor
            The output tensor from `compute_forward`.
        batch : PaddedBatch
            This batch object contains all the relevant tensors for computation.
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, or sb.Stage.TEST.
        Returns
        -------
        loss : torch.Tensor
            A one-element tensor used for backpropagating the gradient.
        """

        _, lens = batch.sig
        labels, _ = batch.digit_encoded

        # Compute the cost function.
        # Your code here. Aim for 1 line
        loss = sb.nnet.losses.nll_loss(predictions, labels, lens)

        # Append this batch of losses to the loss metric for easy
        self.loss_metric.append(
            batch.id, predictions, labels, lens, reduction="batch"
        )

        # Compute classification error at test time
        if stage != sb.Stage.TRAIN:
            self.error_metrics.append(batch.id, predictions, labels, lens)

        return loss

    def on_stage_start(self, stage, epoch=None):
        """Gets called at the beginning of each epoch.
        Arguments
        ---------
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, or sb.Stage.TEST.
        epoch : int
            The currently-starting epoch. This is passed
            `None` during the test stage.
        """

        # Set up statistics trackers for this stage
        self.loss_metric = sb.utils.metric_stats.MetricStats(
            metric=sb.nnet.losses.nll_loss
        )

        # Set up evaluation-only statistics trackers
        if stage != sb.Stage.TRAIN:
            self.error_metrics = self.hparams.error_stats()

    def on_stage_end(self, stage, stage_loss, epoch=None):
        """Gets called at the end of an epoch.
        Arguments
        ---------
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, sb.Stage.TEST
        stage_loss : float
            The average loss for all of the data processed in this stage.
        epoch : int
            The currently-starting epoch. This is passed
            `None` during the test stage.
        """

        # Store the train loss until the validation stage.
        if stage == sb.Stage.TRAIN:
            self.train_loss = stage_loss

        # Summarize the statistics from the stage for record-keeping.
        else:
            stats = {
                "loss": stage_loss,
                "error": self.error_metrics.summarize("average"),
            }

        # At the end of validation...
        if stage == sb.Stage.VALID:

            old_lr, new_lr = self.hparams.lr_annealing(epoch)
            sb.nnet.schedulers.update_learning_rate(self.optimizer, new_lr)

            # The train_logger writes a summary to stdout and to the logfile.
            self.hparams.train_logger.log_stats(
                {"Epoch": epoch, "lr": old_lr},
                train_stats={"loss": self.train_loss},
                valid_stats=stats,
            )

            # Save the current checkpoint and delete previous checkpoints,
            self.checkpointer.save_and_keep_only(meta=stats, min_keys=["error"])

        # We also write statistics about test data to stdout and to the logfile.
        if stage == sb.Stage.TEST:
            self.hparams.train_logger.log_stats(
                {"Epoch loaded": self.hparams.epoch_counter.current},
                test_stats=stats,
            )


def dataio_prep(hparams):
    """This function prepares the datasets to be used in the brain class.
    It also defines the data processing pipeline through user-defined functions.
    We expect `prepare_mini_librispeech` to have been called before this,
    so that the `train.json`, `valid.json`,  and `valid.json` manifest files
    are available.
    Arguments
    ---------
    hparams : dict
        This dictionary is loaded from the `train.yaml` file, and it includes
        all the hyperparameters needed for dataset construction and loading.
    Returns
    -------
    datasets : dict
        Contains two keys, "train" and "valid" that correspond
        to the appropriate DynamicItemDataset object.
    """

    # Initialization of the label encoder. The label encoder assigns to each
    # of the observed label a unique index (e.g, 'digit0': 0, 'digit1': 1, ..)
    label_encoder = sb.dataio.encoder.CategoricalEncoder()

    # Define audio pipeline
    @sb.utils.data_pipeline.takes("wav")
    @sb.utils.data_pipeline.provides("sig")
    def audio_pipeline(wav):
        """Load the signal, and pass it and its length to the corruption class.
        This is done on the CPU in the `collate_fn`."""
        sig, fs = torchaudio.load(wav)

        # Resampling
        # Your code here. Aim for 1-2 lines
        sig = torchaudio.functional.resample(sig, fs, 16000).squeeze(0)
        return sig

    # Define label pipeline:
    @sb.utils.data_pipeline.takes("digit")
    @sb.utils.data_pipeline.provides("digit", "digit_encoded")
    def label_pipeline(digit):
        """Defines the pipeline to process the digit labels.
        Note that we have to assign a different integer to each class
        through the label encoder.
        """
        yield digit
        digit_encoded = label_encoder.encode_label_torch(digit)
        yield digit_encoded

    # Define datasets. We also connect the dataset with the data processing
    # functions defined above.
    datasets = {}
    data_info = {
        "train": hparams["train_annotation"],
        "valid": hparams["valid_annotation"],
        "test": hparams["test_annotation"],
    }
    hparams["dataloader_options"]["shuffle"] = True
    for dataset in data_info:
        datasets[dataset] = sb.dataio.dataset.DynamicItemDataset.from_json(
            json_path=data_info[dataset],
            dynamic_items=[audio_pipeline, label_pipeline],
            output_keys=["id", "sig", "digit_encoded"],
        )

    # Load or compute the label encoder (with multi-GPU DDP support)
    # Please, take a look into the lab_enc_file to see the label to index
    # mapping.
    lab_enc_file = os.path.join(hparams["save_folder"], "label_encoder.txt")
    label_encoder.load_or_create(
        path=lab_enc_file,
        from_didatasets=[datasets["train"]],
        output_key="digit",
    )

    return datasets


# Recipe begins!
if __name__ == "__main__":

    # Reading command line arguments.
    hparams_file, run_opts, overrides = sb.parse_arguments(sys.argv[1:])

    # Load hyperparameters file with command-line overrides.
    with open(hparams_file) as fin:
        hparams = load_hyperpyyaml(fin,  overrides)

    # Create experiment directory
    sb.create_experiment_directory(
        experiment_directory=hparams["output_folder"],
        hyperparams_to_save=hparams_file,
        overrides=overrides,
    )

    # Create dataset objects "train", "valid", and "test".
    datasets = dataio_prep(hparams)

    # Download and Pretrain the encoder
    hparams["pretrainer"].collect_files()
    hparams["pretrainer"].load_collected()
    hparams["encoder"].to(run_opts["device"])

    # Initialize the Brain object to prepare for mask training.
    digit_brain = DigitBrain(
        modules=hparams["modules"],
        opt_class=hparams["opt_class"],
        hparams=hparams,
        run_opts=run_opts,
        checkpointer=hparams["checkpointer"],
    )

    # The `fit()` method iterates the training loop, calling the methods
    # necessary to update the parameters of the model. Since all objects
    # with changing state are managed by the Checkpointer, training can be
    # stopped at any point, and will be resumed on next call.
    digit_brain.fit(
        epoch_counter=digit_brain.hparams.epoch_counter,
        train_set=datasets["train"],
        valid_set=datasets["valid"],
        train_loader_kwargs=hparams["dataloader_options"],
        valid_loader_kwargs=hparams["dataloader_options"],
    )

    # Load the best checkpoint for evaluation
    test_stats = digit_brain.evaluate(
        test_set=datasets["test"],
        min_key="error",
        test_loader_kwargs=hparams["dataloader_options"],
    )
# Out:
# Overwriting train.py

# %% [markdown]
# **Run the code below** to start training.

# %%
# To start from scratch, you need to remove the output folder.
# Otherwise, speechbrain starts from the last valid checkpoint.
#!rm -rf ./results/AudioMNIST/Classifier-frozen/

# !python train.py hparams_classifier_finetuned.yaml --output_folder=results/AudioMNIST/Classifier-frozen/
# Out:
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: results/AudioMNIST/Classifier-frozen/
# speechbrain.dataio.encoder - Load called, but CategoricalEncoder is not empty. Loaded data will overwrite everything. This is normal if there is e.g. an unk label defined at init.
# speechbrain.pretrained.fetching - Destination encoder_best.ckpt: local file in /content/encoder_best.ckpt.
# speechbrain.utils.parameter_transfer - Set local path in self.paths[encoder] = results/AudioMNIST/Classifier-frozen/save/encoder.ckpt
# speechbrain.utils.parameter_transfer - Loading pretrained files for: encoder
# speechbrain.utils.parameter_transfer - Redirecting (loading from local path): results/AudioMNIST/Classifier-frozen/save/encoder.ckpt -> results/AudioMNIST/Classifier-frozen/save/encoder.ckpt
# speechbrain.core - 8.5k trainable parameters in DigitBrain
# speechbrain.utils.checkpoints - Would load a checkpoint here, but none found yet.
# speechbrain.utils.epoch_loop - Going into epoch 1
#   0% 0/79 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/speechbrain/dataio/encoder.py:722: UserWarning: CategoricalEncoder.expect_len was never called: assuming category count of 10 to be correct! Sanity check your encoder using `.expect_len`. Ensure that downstream code also uses the correct size. If you are sure this does not apply to you, use `.ignore_len`.
#   warnings.warn(
# 100% 79/79 [00:42<00:00,  1.84it/s, train_loss=2.31]
# 100% 32/32 [00:17<00:00,  1.82it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.001 to 0.00097
# speechbrain.utils.train_logger - Epoch: 1, lr: 1.00e-03 - train loss: 2.31 - valid loss: 2.32, valid error: 9.02e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-12-36+00
# speechbrain.utils.epoch_loop - Going into epoch 2
# 100% 79/79 [00:42<00:00,  1.86it/s, train_loss=2.27]
# 100% 32/32 [00:17<00:00,  1.85it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00097 to 0.00094
# speechbrain.utils.train_logger - Epoch: 2, lr: 9.69e-04 - train loss: 2.27 - valid loss: 2.28, valid error: 8.61e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-13-36+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-12-36+00
# speechbrain.utils.epoch_loop - Going into epoch 3
# 100% 79/79 [00:42<00:00,  1.84it/s, train_loss=2.26]
# 100% 32/32 [00:17<00:00,  1.84it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00094 to 0.00091
# speechbrain.utils.train_logger - Epoch: 3, lr: 9.38e-04 - train loss: 2.26 - valid loss: 2.27, valid error: 8.54e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-14-37+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-13-36+00
# speechbrain.utils.epoch_loop - Going into epoch 4
# 100% 79/79 [00:42<00:00,  1.85it/s, train_loss=2.24]
# 100% 32/32 [00:17<00:00,  1.83it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00091 to 0.00088
# speechbrain.utils.train_logger - Epoch: 4, lr: 9.07e-04 - train loss: 2.24 - valid loss: 2.28, valid error: 8.60e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-15-37+00
# speechbrain.utils.epoch_loop - Going into epoch 5
# 100% 79/79 [00:43<00:00,  1.83it/s, train_loss=2.23]
# 100% 32/32 [00:17<00:00,  1.83it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00088 to 0.00084
# speechbrain.utils.train_logger - Epoch: 5, lr: 8.76e-04 - train loss: 2.23 - valid loss: 2.26, valid error: 8.30e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-16-38+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-14-37+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-15-37+00
# speechbrain.utils.epoch_loop - Going into epoch 6
# 100% 79/79 [00:42<00:00,  1.86it/s, train_loss=2.22]
# 100% 32/32 [00:17<00:00,  1.81it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00084 to 0.00081
# speechbrain.utils.train_logger - Epoch: 6, lr: 8.45e-04 - train loss: 2.22 - valid loss: 2.26, valid error: 8.33e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-17-38+00
# speechbrain.utils.epoch_loop - Going into epoch 7
# 100% 79/79 [00:43<00:00,  1.82it/s, train_loss=2.22]
# 100% 32/32 [00:17<00:00,  1.84it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00081 to 0.00078
# speechbrain.utils.train_logger - Epoch: 7, lr: 8.14e-04 - train loss: 2.22 - valid loss: 2.28, valid error: 8.79e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-18-39+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-17-38+00
# speechbrain.utils.epoch_loop - Going into epoch 8
# 100% 79/79 [00:42<00:00,  1.86it/s, train_loss=2.22]
# 100% 32/32 [00:17<00:00,  1.85it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00078 to 0.00075
# speechbrain.utils.train_logger - Epoch: 8, lr: 7.83e-04 - train loss: 2.22 - valid loss: 2.27, valid error: 8.40e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-19-39+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-18-39+00
# speechbrain.utils.epoch_loop - Going into epoch 9
# 100% 79/79 [00:42<00:00,  1.87it/s, train_loss=2.22]
# 100% 32/32 [00:17<00:00,  1.87it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00075 to 0.00072
# speechbrain.utils.train_logger - Epoch: 9, lr: 7.52e-04 - train loss: 2.22 - valid loss: 2.29, valid error: 8.59e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-20-38+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-19-39+00
# speechbrain.utils.epoch_loop - Going into epoch 10
# 100% 79/79 [00:41<00:00,  1.91it/s, train_loss=2.21]
# 100% 32/32 [00:17<00:00,  1.82it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00072 to 0.00069
# speechbrain.utils.train_logger - Epoch: 10, lr: 7.21e-04 - train loss: 2.21 - valid loss: 2.29, valid error: 8.85e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-21-37+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-20-38+00
# speechbrain.utils.epoch_loop - Going into epoch 11
# 100% 79/79 [00:41<00:00,  1.91it/s, train_loss=2.2]
# 100% 32/32 [00:18<00:00,  1.77it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00069 to 0.00066
# speechbrain.utils.train_logger - Epoch: 11, lr: 6.90e-04 - train loss: 2.20 - valid loss: 2.27, valid error: 8.36e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-22-37+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-21-37+00
# speechbrain.utils.epoch_loop - Going into epoch 12
# 100% 79/79 [00:41<00:00,  1.92it/s, train_loss=2.21]
# 100% 32/32 [00:17<00:00,  1.78it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00066 to 0.00063
# speechbrain.utils.train_logger - Epoch: 12, lr: 6.59e-04 - train loss: 2.21 - valid loss: 2.27, valid error: 8.51e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-23-36+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-22-37+00
# speechbrain.utils.epoch_loop - Going into epoch 13
# 100% 79/79 [00:41<00:00,  1.91it/s, train_loss=2.2]
# 100% 32/32 [00:17<00:00,  1.78it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00063 to 0.0006
# speechbrain.utils.train_logger - Epoch: 13, lr: 6.28e-04 - train loss: 2.20 - valid loss: 2.25, valid error: 8.35e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-24-35+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-23-36+00
# speechbrain.utils.epoch_loop - Going into epoch 14
# 100% 79/79 [00:41<00:00,  1.92it/s, train_loss=2.18]
# 100% 32/32 [00:18<00:00,  1.78it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0006 to 0.00057
# speechbrain.utils.train_logger - Epoch: 14, lr: 5.97e-04 - train loss: 2.18 - valid loss: 2.27, valid error: 8.28e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-25-35+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-16-38+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-24-35+00
# speechbrain.utils.epoch_loop - Going into epoch 15
# 100% 79/79 [00:41<00:00,  1.92it/s, train_loss=2.19]
# 100% 32/32 [00:17<00:00,  1.86it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00057 to 0.00053
# speechbrain.utils.train_logger - Epoch: 15, lr: 5.66e-04 - train loss: 2.19 - valid loss: 2.29, valid error: 8.60e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-26-33+00
# speechbrain.utils.epoch_loop - Going into epoch 16
# 100% 79/79 [00:41<00:00,  1.89it/s, train_loss=2.19]
# 100% 32/32 [00:17<00:00,  1.84it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00053 to 0.0005
# speechbrain.utils.train_logger - Epoch: 16, lr: 5.34e-04 - train loss: 2.19 - valid loss: 2.30, valid error: 8.43e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-27-32+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-26-33+00
# speechbrain.utils.epoch_loop - Going into epoch 17
# 100% 79/79 [00:42<00:00,  1.84it/s, train_loss=2.19]
# 100% 32/32 [00:17<00:00,  1.86it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.0005 to 0.00047
# speechbrain.utils.train_logger - Epoch: 17, lr: 5.03e-04 - train loss: 2.19 - valid loss: 2.27, valid error: 8.50e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-28-33+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-27-32+00
# speechbrain.utils.epoch_loop - Going into epoch 18
# 100% 79/79 [00:42<00:00,  1.86it/s, train_loss=2.19]
# 100% 32/32 [00:17<00:00,  1.84it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00047 to 0.00044
# speechbrain.utils.train_logger - Epoch: 18, lr: 4.72e-04 - train loss: 2.19 - valid loss: 2.29, valid error: 8.59e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-29-33+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-28-33+00
# speechbrain.utils.epoch_loop - Going into epoch 19
# 100% 79/79 [00:42<00:00,  1.87it/s, train_loss=2.19]
# 100% 32/32 [00:17<00:00,  1.86it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00044 to 0.00041
# speechbrain.utils.train_logger - Epoch: 19, lr: 4.41e-04 - train loss: 2.19 - valid loss: 2.28, valid error: 8.55e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-30-32+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-29-33+00
# speechbrain.utils.epoch_loop - Going into epoch 20
# 100% 79/79 [00:42<00:00,  1.88it/s, train_loss=2.18]
# 100% 32/32 [00:17<00:00,  1.86it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00041 to 0.00038
# speechbrain.utils.train_logger - Epoch: 20, lr: 4.10e-04 - train loss: 2.18 - valid loss: 2.28, valid error: 8.62e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-31-32+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-30-32+00
# speechbrain.utils.epoch_loop - Going into epoch 21
# 100% 79/79 [00:42<00:00,  1.84it/s, train_loss=2.17]
# 100% 32/32 [00:17<00:00,  1.85it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00038 to 0.00035
# speechbrain.utils.train_logger - Epoch: 21, lr: 3.79e-04 - train loss: 2.17 - valid loss: 2.28, valid error: 8.43e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-32-32+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-31-32+00
# speechbrain.utils.epoch_loop - Going into epoch 22
# 100% 79/79 [00:42<00:00,  1.85it/s, train_loss=2.17]
# 100% 32/32 [00:17<00:00,  1.84it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00035 to 0.00032
# speechbrain.utils.train_logger - Epoch: 22, lr: 3.48e-04 - train loss: 2.17 - valid loss: 2.28, valid error: 8.40e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-33-32+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-32-32+00
# speechbrain.utils.epoch_loop - Going into epoch 23
# 100% 79/79 [00:42<00:00,  1.86it/s, train_loss=2.16]
# 100% 32/32 [00:17<00:00,  1.84it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00032 to 0.00029
# speechbrain.utils.train_logger - Epoch: 23, lr: 3.17e-04 - train loss: 2.16 - valid loss: 2.28, valid error: 8.66e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-34-32+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-33-32+00
# speechbrain.utils.epoch_loop - Going into epoch 24
# 100% 79/79 [00:42<00:00,  1.88it/s, train_loss=2.17]
# 100% 32/32 [00:17<00:00,  1.81it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00029 to 0.00026
# speechbrain.utils.train_logger - Epoch: 24, lr: 2.86e-04 - train loss: 2.17 - valid loss: 2.26, valid error: 8.33e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-35-32+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-34-32+00
# speechbrain.utils.epoch_loop - Going into epoch 25
# 100% 79/79 [00:42<00:00,  1.85it/s, train_loss=2.17]
# 100% 32/32 [00:17<00:00,  1.81it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00026 to 0.00022
# speechbrain.utils.train_logger - Epoch: 25, lr: 2.55e-04 - train loss: 2.17 - valid loss: 2.28, valid error: 8.41e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-36-33+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-35-32+00
# speechbrain.utils.epoch_loop - Going into epoch 26
# 100% 79/79 [00:42<00:00,  1.87it/s, train_loss=2.17]
# 100% 32/32 [00:17<00:00,  1.79it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00022 to 0.00019
# speechbrain.utils.train_logger - Epoch: 26, lr: 2.24e-04 - train loss: 2.17 - valid loss: 2.27, valid error: 8.35e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-37-33+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-36-33+00
# speechbrain.utils.epoch_loop - Going into epoch 27
# 100% 79/79 [00:41<00:00,  1.88it/s, train_loss=2.16]
# 100% 32/32 [00:18<00:00,  1.77it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00019 to 0.00016
# speechbrain.utils.train_logger - Epoch: 27, lr: 1.93e-04 - train loss: 2.16 - valid loss: 2.27, valid error: 8.35e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-38-33+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-37-33+00
# speechbrain.utils.epoch_loop - Going into epoch 28
# 100% 79/79 [00:41<00:00,  1.89it/s, train_loss=2.17]
# 100% 32/32 [00:18<00:00,  1.76it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00016 to 0.00013
# speechbrain.utils.train_logger - Epoch: 28, lr: 1.62e-04 - train loss: 2.17 - valid loss: 2.27, valid error: 8.30e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-39-33+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-38-33+00
# speechbrain.utils.epoch_loop - Going into epoch 29
# 100% 79/79 [00:41<00:00,  1.89it/s, train_loss=2.15]
# 100% 32/32 [00:18<00:00,  1.77it/s]
# speechbrain.nnet.schedulers - Changing lr from 0.00013 to 0.0001
# speechbrain.utils.train_logger - Epoch: 29, lr: 1.31e-04 - train loss: 2.15 - valid loss: 2.27, valid error: 8.38e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-40-33+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-39-33+00
# speechbrain.utils.epoch_loop - Going into epoch 30
# 100% 79/79 [00:41<00:00,  1.88it/s, train_loss=2.17]
# 100% 32/32 [00:18<00:00,  1.77it/s]
# speechbrain.utils.train_logger - Epoch: 30, lr: 1.00e-04 - train loss: 2.17 - valid loss: 2.28, valid error: 8.37e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-41-33+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-40-33+00
# speechbrain.utils.checkpoints - Loading a checkpoint from results/AudioMNIST/Classifier-frozen/save/CKPT+2024-02-04+19-25-35+00
# 100% 32/32 [00:17<00:00,  1.87it/s]
# speechbrain.utils.train_logger - Epoch loaded: 14 - test loss: 2.30, test error: 8.29e-01

# %% [markdown]
# You should obtain something like this:
#
#
#
# ```
# Epoch: 1, lr: 1.00e-03 - train loss: 2.29 - valid loss: 2.32, valid error: 8.86e-01
# Epoch: 2, lr: 9.69e-04 - train loss: 2.19 - valid loss: 2.21, valid error: 7.85e-01
# Epoch: 3, lr: 9.38e-04 - train loss: 2.14 - valid loss: 2.19, valid error: 7.74e-01
# Epoch: 4, lr: 9.07e-04 - train loss: 2.08 - valid loss: 2.18, valid error: 7.77e-01
# Epoch: 5, lr: 8.76e-04 - train loss: 2.04 - valid loss: 2.13, valid error: 7.78e-01
# Epoch: 6, lr: 8.45e-04 - train loss: 2.01 - valid loss: 2.13, valid error: 7.84e-01
# Epoch: 7, lr: 8.14e-04 - train loss: 1.99 - valid loss: 2.10, valid error: 7.67e-01
# Epoch: 8, lr: 7.83e-04 - train loss: 1.97 - valid loss: 2.09, valid error: 7.83e-01
# Epoch: 9, lr: 7.52e-04 - train loss: 1.95 - valid loss: 2.08, valid error: 7.57e-01
# Epoch: 10, lr: 7.21e-04 - train loss: 1.93 - valid loss: 2.08, valid error: 7.46e-01
# Epoch: 11, lr: 6.90e-04 - train loss: 1.93 - valid loss: 2.06, valid error: 7.46e-01
# Epoch: 12, lr: 6.59e-04 - train loss: 1.91 - valid loss: 2.09, valid error: 7.79e-01
# Epoch: 13, lr: 6.28e-04 - train loss: 1.92 - valid loss: 2.06, valid error: 7.57e-01
# Epoch: 14, lr: 5.97e-04 - train loss: 1.89 - valid loss: 2.09, valid error: 7.58e-01
# Epoch: 15, lr: 5.66e-04 - train loss: 1.89 - valid loss: 2.05, valid error: 7.62e-01
# Epoch: 16, lr: 5.34e-04 - train loss: 1.87 - valid loss: 2.05, valid error: 7.75e-01
# Epoch: 17, lr: 5.03e-04 - train loss: 1.85 - valid loss: 2.03, valid error: 7.34e-01
# Epoch: 18, lr: 4.72e-04 - train loss: 1.86 - valid loss: 2.05, valid error: 7.67e-01
# Epoch: 19, lr: 4.41e-04 - train loss: 1.85 - valid loss: 2.04, valid error: 7.80e-01
# Epoch: 20, lr: 4.10e-04 - train loss: 1.85 - valid loss: 2.03, valid error: 7.42e-01
# Epoch: 21, lr: 3.79e-04 - train loss: 1.83 - valid loss: 2.03, valid error: 7.60e-01
# Epoch: 22, lr: 3.48e-04 - train loss: 1.82 - valid loss: 2.02, valid error: 7.57e-01
# Epoch: 23, lr: 3.17e-04 - train loss: 1.82 - valid loss: 2.01, valid error: 7.48e-01
# Epoch: 24, lr: 2.86e-04 - train loss: 1.81 - valid loss: 2.02, valid error: 7.41e-01
# Epoch: 25, lr: 2.55e-04 - train loss: 1.81 - valid loss: 2.01, valid error: 7.57e-01
# Epoch: 26, lr: 2.24e-04 - train loss: 1.81 - valid loss: 1.99, valid error: 7.45e-01
# Epoch: 27, lr: 1.93e-04 - train loss: 1.79 - valid loss: 2.00, valid error: 7.48e-01
# Epoch: 28, lr: 1.62e-04 - train loss: 1.80 - valid loss: 2.00, valid error: 7.52e-01
# Epoch: 29, lr: 1.31e-04 - train loss: 1.79 - valid loss: 2.00, valid error: 7.63e-01
# Epoch: 30, lr: 1.00e-04 - train loss: 1.79 - valid loss: 2.00, valid error: 7.60e-01
# Epoch loaded: 17 - test loss: 2.13, test error: 7.56e-01
#
#
# ```

# %% [markdown]
# ### **Conclusion**
# We trained an autoencoder and injected the representation learned by the encoder into a digit classifier. We tested two different conditions:
#
# 1. Fine-tuning the encoder
# 2. Freezing the encoder
#
# I obtained the following classification error rates:
# - Pretrained encoder: 54.9%
# - Frozen encoder: 75.6%
#
#
# Variations (also pretty large) over these results are possible due to the small dataset used and different initialization points.
#
# Freezing the encoder does not provide good results because the classifier has little capacity.
#
# Note that the results obtained in this lab are much worse than those achieved in the last lab. In the previous lab, we were using hand-crafted features that are very effective. In this case, we learned the features from the raw audio directly using a small model trained on little data. This makes this task very challenging.
#
# This was just a very formative exercise and keep in mind that you can easily do better with a much larger dataset and a bigger model.
#
#
# That's all!
